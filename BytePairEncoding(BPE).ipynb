# %%
import numpy as numpy
import pandas as pd
import re
from collections import defaultdict
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Preprocesing

# %%
#load the dataset
indiana_data = pd.read_csv("data/indiana/preprocessed-indiana-cxr-reports.csv")
indiana_data.head()
# Out:
#       COMPARISON                               INDICATION  \
# 0          none.                            no indication
# 1  no comparison               slipped back on right side
# 2  no comparison  bone marrow transplant evaluation. aml.
# 3          none.                         chest pain and .
# 4          none.           mid to lower back pain since .
#
#                                             FINDINGS  \
# 0  heart size normal. lungs are clear. are normal...
# 1  the heart size and pulmonary vascularity appea...
# 2  the heart size and pulmonary vascularity appea...
# 3  the heart is normal in size and contour. the l...
# 4  the heart is normal in size and contour. the l...
#
#                           IMPRESSION  indication_count  findings_count  \
# 0                       normal chest                 2              17
# 1     no evidence of active disease.                 5              36
# 2     no evidence of active disease.                 5              38
# 3  no acute cardiopulmonary disease.                 4              41
# 4  no acute cardiopulmonary disease.                 7              22
#
#    impression_count
# 0                 2
# 1                 5
# 2                 5
# 3                 4
# 4                 4

# %%
indiana_data.shape
# Out:
# (3418, 7)

# %%
# Since we are working on report summarization, we don't need the first two columns
# drop the unnecessary columns
indiana_data.drop(columns=['COMPARISON', 'INDICATION', 'indication_count', 'findings_count', 'impression_count'], inplace=True)
indiana_data.shape
# Out:
# (3418, 2)

# %%
# split the data into train, val and test
train, temp = train_test_split(indiana_data, test_size=0.1, random_state=42)
val, test = train_test_split(temp, test_size=0.5, random_state=42)
print("Train data shape:", train.shape)
print("Val data shape:", val.shape)
print("Test data shape:", test.shape)
# Out:
# Train data shape: (3076, 2)
# Val data shape: (171, 2)
# Test data shape: (171, 2)

# %%
# total number of unigram words in the findings training data
main_str = train.FINDINGS.values.tolist()
total_unique_words= len(list(set(' '.join(main_str).split(" "))))
print(f"There are total of {total_unique_words} unique unigrams words in the report")
# Out:
# There are total of 2033 unique unigrams words in the report

# %% [markdown]
# There are three main task of NLP Model training procedure, that is
# 1. Tokenization
# 2. Vectorization
# 3. Model Training

# %% [markdown]
# # Tokenization

# %%
# read the findings into  list of sentences
findings_list = train.FINDINGS.values.tolist()

#write findings to text file
dest_file = open("data/indiana/findings.txt","w")
for sentence in findings_list:
    dest_file.write(sentence +"\n")
dest_file.close()
#write impression to text file
dest_file2 = open("data/indiana/impressions.txt","w")
for sentence in train.IMPRESSION.values:
    dest_file2.write(sentence +"\n")
    
dest_file2.close()

# %%
# findings_list

# %%
# read the vocab
vocab = defaultdict(int)
with open('data/indiana/findings.txt', 'r', encoding='utf-8') as f:

    for sent in f:
        words = sent.strip().split()
        for word in words:
            vocab[' '.join(list(word)) + ' </w>'] += 1

# %%
vocab
# Out:
# defaultdict(int,
#             {'t h e </w>': 5778,
#              'l u n g s </w>': 1719,
#              'r e m a i n </w>': 34,
#              'h y p e r e x p a n d e d . </w>': 32,
#              'n o </w>': 4006,
#              'm a s s e s </w>': 15,
#              'o r </w>': 2183,
#              'i n f i l t r a t e s </w>': 32,
#              'i n </w>': 1320,
#              'l u n g s . </w>': 80,
#              'p l e u r a l </w>': 2246,
#              'm e d i a s t i n a l </w>': 759,
#              'a i r </w>': 204,
#              'c o l l e c t i o n s . </w>': 4,
#              'h e a r t </w>': 1903,
#              's i z e </w>': 1381,
#              'n o r m a l . </w>': 1073,
#              'i s </w>': 3977,
#              'n o r m a l </w>': 2097,
#              's i z e . </w>': 355,
#              'm e d i a s t i n u m </w>': 512,
#              'u n r e m a r k a b l e . </w>': 488,
#              'a </w>': 494,
#              't o r t u o u s </w>': 69,
#              'c a l c i f i e d </w>': 345,
#              't h o r a c i c </w>': 520,
#              'a o r t a </w>': 106,
#              'p r e s e n t . </w>': 71,
#              'a r e </w>': 3934,
#              'h y p e r e x p a n d e d </w>': 47,
#              'c o n s i s t e n t </w>': 83,
#              'w i t h </w>': 578,
#              'e m p h y s e m a . </w>': 36,
#              't h e r e </w>': 2176,
#              'e f f u s i o n </w>': 1070,
#              'p n e u m o t h o r a x </w>': 1127,
#              'f o c a l </w>': 1566,
#              'a i r s p a c e </w>': 741,
#              'd i s e a s e . </w>': 326,
#              'c l e a r </w>': 622,
#              'b i l a t e r a l l y . </w>': 184,
#              'c a r d i a c </w>': 392,
#              'a n d </w>': 2551,
#              's i l h o u e t t e s </w>': 52,
#              'p u l m o n a r y </w>': 1085,
#              'v a s c u l a t u r e </w>': 248,
#              'e f f u s i o n . </w>': 965,
#              'a c u t e </w>': 610,
#              'b o n y </w>': 468,
#              'a b n o r m a l i t y . </w>': 288,
#              'c a r d i o m e d i a s t i n a l </w>': 731,
#              's i l h o u e t t e </w>': 791,
#              'w i t h i n </w>': 1386,
#              'l i m i t s </w>': 364,
#              'f o r </w>': 320,
#              'c o n t o u r . </w>': 276,
#              'r i g h t </w>': 874,
#              'l o w e r </w>': 225,
#              'l o b e </w>': 167,
#              'g r a n u l o m a </w>': 110,
#              'n o r m a l l y </w>': 65,
#              'i n f l a t e d </w>': 70,
#              'w i t h o u t </w>': 403,
#              'e v i d e n c e </w>': 321,
#              'o f </w>': 2228,
#              'd i s e a s e </w>': 226,
#              'p n e u m o t h o r a x . </w>': 1058,
#              'd e g e n e r a t i v e </w>': 427,
#              'c h a n g e s </w>': 502,
#              's p i n e . </w>': 418,
#              's t a b l e </w>': 464,
#              'e l e v a t i o n </w>': 37,
#              'l e f t </w>': 751,
#              'h e m i d i a p h r a g m . </w>': 48,
#              'c l e a r . </w>': 767,
#              'f l u i d </w>': 24,
#              'a p p r e c i a t e d . </w>': 7,
#              'c h o l e c y s t e c t o m y </w>': 9,
#              'c l i p s </w>': 67,
#              'n o t e d </w>': 82,
#              'u p p e r </w>': 316,
#              'q u a d r a n t . </w>': 16,
#              'f r o n t a l </w>': 99,
#              'l a t e r a l </w>': 275,
#              'v i e w s </w>': 67,
#              'c h e s t </w>': 196,
#              's h o w </w>': 75,
#              'c o n f i g u r a t i o n </w>': 19,
#              's i l h o u e t t e . </w>': 106,
#              'c o n t o u r </w>': 193,
#              'c e n t r a l </w>': 96,
#              'a i r w a y s </w>': 17,
#              'l u n g </w>': 559,
#              'v o l u m e s . </w>': 91,
#              'q u a d r a n t </w>': 10,
#              's u r g i c a l </w>': 77,
#              'p e r h a p s </w>': 3,
#              'f r o m </w>': 97,
#              'c h o l e c y s t e c t o m y . </w>': 7,
#              'c o n s o l i d a t i o n </w>': 601,
#              'e n d p l a t e </w>': 26,
#              'o v e r l i e </w>': 10,
#              'b o n e </w>': 65,
#              'c o n s o l i d a t i o n s . </w>': 41,
#              'o s s e o u s </w>': 367,
#              'f i n d i n g s . </w>': 112,
#              'm i l d l y </w>': 116,
#              't o </w>': 305,
#              'm o d e r a t e l y </w>': 15,
#              'e n l a r g e d </w>': 48,
#              'd i s t a l </w>': 26,
#              't i p </w>': 89,
#              'd u a l </w>': 13,
#              'l u m e n </w>': 5,
#              'c a t h e t e r </w>': 47,
#              'n e a r </w>': 25,
#              'c a v a l </w>': 6,
#              'a t r i a l </w>': 14,
#              'j u n c t i o n . </w>': 27,
#              'm i l d </w>': 416,
#              'v a s c u l a r </w>': 109,
#              'c e p h a l i z a t i o n </w>': 1,
#              'd e f i n i t e </w>': 102,
#              'i n t e r s t i t i a l </w>': 120,
#              'e d e m a </w>': 59,
#              'a l v e o l a r </w>': 74,
#              'c o n s o l i d a t i o n . </w>': 349,
#              'd e m o n s t r a t e d . </w>': 23,
#              'c o n t o u r s . </w>': 113,
#              'i n t e r v a l </w>': 71,
#              'r e m o v a l </w>': 12,
#              's i d e d </w>': 72,
#              'i n t r a v e n o u s </w>': 1,
#              'c a t h e t e r . </w>': 7,
#              'o p a c i t i e s </w>': 201,
#              'o b s c u r i n g </w>': 2,
#              'h e m i d i a p h r a g m s </w>': 7,
#              's l i g h t l y </w>': 24,
#              'i m p r o v e d </w>': 11,
#              'p r i o r </w>': 175,
#              'e x a m i n a t i o n . </w>': 50,
#              'r i b </w>': 127,
#              'f r a c t u r e s </w>': 45,
#              'a g a i n </w>': 83,
#              'n o t e d . </w>': 183,
#              'a p p e a r a n c e . </w>': 99,
#              'a r e a s </w>': 100,
#              's p i n e </w>': 143,
#              'a p p e a r s </w>': 94,
#              'i n t a c t . </w>': 314,
#              'd i s p l a c e d </w>': 59,
#              'f r a c t u r e s . </w>': 41,
#              't w o i m a g e s . </w>': 19,
#              'e n g o r g e m e n t </w>': 16,
#              'a p p e a r </w>': 378,
#              'i d e n t i f i e d . </w>': 190,
#              'c o n v i n c i n g </w>': 14,
#              'c o n t o u r s </w>': 370,
#              'l o w </w>': 152,
#              'v o l u m e s </w>': 121,
#              'o p a c i t y </w>': 282,
#              'm u l t i l e v e l </w>': 32,
#              't o r t u o s i t y </w>': 50,
#              'a o r t a . </w>': 154,
#              'v a s c u l a r i t y </w>': 313,
#              's t r u c t u r e s </w>': 519,
#              'p a t i e n t </w>': 84,
#              'a g e . </w>': 36,
#              'l o b u l a t e d </w>': 3,
#              'p a r a t r a c h e a l </w>': 15,
#              's t r i p e </w>': 3,
#              'p o s s i b l y </w>': 20,
#              's t r u c t u r e </w>': 2,
#              'l y m p h </w>': 80,
#              '. </w>': 288,
#              'o t h e r w i s e </w>': 127,
#              'a t </w>': 105,
#              's c a t t e r e d </w>': 66,
#              'g r a n u l o m a s . </w>': 43,
#              'l a r g e </w>': 390,
#              'a p p r e c i a b l e </w>': 1,
#              'u n f o l d e d </w>': 4,
#              'd e s c e n d i n g </w>': 19,
#              'a o r t i c </w>': 123,
#              'c u r v a t u r e </w>': 15,
#              'e x a g g e r a t e d </w>': 12,
#              'k y p h o s i s . </w>': 13,
#              'd i f f u s e l y </w>': 5,
#              'o s t e o p e n i c . </w>': 2,
#              'm i n i m a l </w>': 98,
#              'a n t e r i o r </w>': 73,
#              'l o s s </w>': 20,
#              's e v e r a l </w>': 14,
#              'v e r t e b r a l </w>': 50,
#              'b o d i e s . </w>': 9,
#              's k e l e t a l </w>': 75,
#              's o f t </w>': 125,
#              't i s s u e s </w>': 76,
#              'l i m i t s . </w>': 964,
#              'w a l l </w>': 21,
#              'm e d i p o r t </w>': 3,
#              'p l a c e m e n t </w>': 8,
#              'v e n o u s </w>': 27,
#              's u p e r i o r </w>': 30,
#              'e f f u s i o n s . </w>': 148,
#              'f r a c t u r e </w>': 54,
#              's e e n </w>': 132,
#              'v e r t e b r a e </w>': 31,
#              't 5 </w>': 1,
#              'l u m b a r </w>': 33,
#              'l 2 </w>': 2,
#              's c l e r o s i s </w>': 4,
#              't h r o u g h o u t </w>': 29,
#              'r i g h t w a r d </w>': 6,
#              'd e v i a t i o n </w>': 3,
#              't r a c h e a </w>': 71,
#              'u n c h a n g e d </w>': 97,
#              'c o m p a r i s o n </w>': 14,
#              's e c o n d a r y </w>': 25,
#              'g o i t e r . </w>': 1,
#              'a d v a n c e d </w>': 3,
#              'c h a n g e </w>': 48,
#              'r e d e m o n s t r a t i o n </w>': 17,
#              'c o p d </w>': 2,
#              'u n c h a n g e d . </w>': 68,
#              'a t h e r o s c l e r o t i c </w>': 91,
#              'c a l c i f i c a t i o n s </w>': 59,
#              's e e n . </w>': 278,
#              'n o n c a l c i f i e d </w>': 10,
#              'n o d u l e . </w>': 20,
#              'm e d i a s t i n u m . </w>': 24,
#              'v i s u a l i z e d </w>': 299,
#              'p l a t e l i k e </w>': 5,
#              'h o r i z o n t a l </w>': 3,
#              'b o t h </w>': 134,
#              'b a s e s </w>': 24,
#              't h r o u g h </w>': 14,
#              't h i s </w>': 82,
#              's c a r r i n g </w>': 79,
#              's u b s e g m e n t a l </w>': 45,
#              'a t e l e c t a s i s . </w>': 105,
#              't </w>': 26,
#              'o s t e o p h y t e s . </w>': 25,
#              'l o b a r </w>': 9,
#              'p n e u m o n i a . </w>': 75,
#              'h i l a r </w>': 125,
#              'g r a n u l o m a . </w>': 45,
#              'c u r v i l i n e a r </w>': 7,
#              'd e n s i t y </w>': 69,
#              'a l o n g </w>': 25,
#              'c o s t o p h r e n i c </w>': 94,
#              's u l c u s </w>': 11,
#              'w h i c h </w>': 102,
#              'm o s t </w>': 30,
#              'r e p r e s e n t s </w>': 27,
#              's k i n f o l d . </w>': 1,
#              'c a l l u s </w>': 3,
#              '9 t h </w>': 11,
#              'r i b . </w>': 20,
#              'b l u n t i n g </w>': 60,
#              'i n c r e a s e d </w>': 80,
#              'o p a c i t i e s . </w>': 86,
#              'a n </w>': 80,
#              'a e r a t i o n </w>': 10,
#              's u b p h r e n i c </w>': 2,
#              'i n t r a p e r i t o n e a l </w>': 39,
#              'e x t r a l u m i n a l </w>': 1,
#              'f r e e </w>': 174,
#              'm i d l i n e . </w>': 62,
#              'c o m p a r e d </w>': 43,
#              't u b u l a r </w>': 2,
#              'd e n s i t i e s </w>': 24,
#              'o v e r l y i n g </w>': 88,
#              'c o r o n a r y </w>': 11,
#              'a r t e r y </w>': 11,
#              's t e n t s . </w>': 2,
#              's m a l l </w>': 148,
#              'r o u n d </w>': 11,
#              'c a l c i f i c </w>': 11,
#              'b i l a t e r a l </w>': 157,
#              'l o b e s </w>': 5,
#              'e x a m i n a t i o n </w>': 93,
#              'r e p r e s e n t </w>': 65,
#              's e q u e l a e </w>': 12,
#              'o l d </w>': 50,
#              'g r a n u l o m a t o u s </w>': 105,
#              'i n f i l t r a t e </w>': 95,
#              'r e v e a l </w>': 31,
#              'a b n o r m a l i t i e s . </w>': 97,
#              'v i e w </w>': 57,
#              'r e v e a l s </w>': 19,
#              'e f f u s i o n s </w>': 196,
#              'p n e u m o t h o r a c e s . </w>': 132,
#              'g e n e r a t o r </w>': 12,
#              't w o d i s t a l </w>': 1,
#              'l e a d s </w>': 41,
#              'a t r i u m </w>': 23,
#              'v e n t r i c l e . </w>': 20,
#              's p o n d y l o s i s . </w>': 50,
#              '4 </w>': 2,
#              'm m </w>': 36,
#              'm i d l u n g </w>': 37,
#              't y p i c a l </w>': 57,
#              'f i n d i n g s </w>': 78,
#              'e d e m a . </w>': 117,
#              's u s p i c i o u s </w>': 88,
#              'c a r d i o m e g a l y </w>': 48,
#              'c a l i b e r </w>': 2,
#              'v a s c u l a t u r e . </w>': 21,
#              'g r o s s l y </w>': 180,
#              'i n t a c t </w>': 31,
#              's t e r n o t o m y </w>': 81,
#              'c l i p s . </w>': 12,
#              'p a t c h y </w>': 66,
#              'b i b a s i l a r </w>': 63,
#              'a t e l e c t a s i s </w>': 106,
#              'e v o l v i n g </w>': 1,
#              's p a c e s </w>': 83,
#              't h o r a x </w>': 127,
#              'c o n s i s t s </w>': 41,
#              'r a d i o g r a p h s </w>': 42,
#              'c h e s t . </w>': 72,
#              'p o s t e r i o r </w>': 74,
#              'e x c l u d e d </w>': 3,
#              'o n </w>': 187,
#              'v i e w . </w>': 46,
#              'a b d o m e n </w>': 36,
#              's p a c e </w>': 151,
#              's u b d i a p h r a g m a t i c </w>': 8,
#              'a i r . </w>': 11,
#              'i n c l u d e d </w>': 1,
#              '1 0 </w>': 6,
#              'n o d u l e </w>': 52,
#              'a p e x </w>': 20,
#              'p r o j e c t i n g </w>': 34,
#              'b e t w e e n </w>': 6,
#              't h i r d </w>': 5,
#              'f o u r t h </w>': 4,
#              'r i b s . </w>': 14,
#              'g u n s h o t </w>': 1,
#              'w o u n d . </w>': 1,
#              'c h r o n i c </w>': 83,
#              'h e a l e d </w>': 16,
#              '1 0 t h </w>': 4,
#              'p o s t e r o l a t e r a l </w>': 4,
#              'f r a c t u r e . </w>': 35,
#              'o s s e u s </w>': 8,
#              'c e r v i c a l </w>': 27,
#              'a r t h r i t i s . </w>': 2,
#              'b r o n c h o v a s c u l a r </w>': 58,
#              'c r o w d i n g </w>': 26,
#              'c a v o a t r i a l </w>': 12,
#              'p r o m i n e n t </w>': 67,
#              'p e r i b r o n c h i a l </w>': 2,
#              'c u f f i n g . </w>': 1,
#              's u b p l e u r a l </w>': 3,
#              'o u t l i n i n g </w>': 1,
#              'f i s s u r e . </w>': 11,
#              't r a c h e o s t o m y </w>': 6,
#              't u b e </w>': 19,
#              '5 </w>': 8,
#              'c m </w>': 47,
#              'a b o v e </w>': 6,
#              'c a r i n a . </w>': 3,
#              'd i f f u s e </w>': 37,
#              'r a d i o g r a p h s . </w>': 2,
#              'n o d u l e s . </w>': 7,
#              'g r a n u l o m a s </w>': 37,
#              's y m m e t r i c </w>': 6,
#              'a p i c a l </w>': 30,
#              's c a r r i n g . </w>': 65,
#              'd i a p h r a g m s </w>': 11,
#              'f l a t t e n e d </w>': 18,
#              's o m e w h a t </w>': 14,
#              's h a p e d . </w>': 1,
#              'c a r d i o t h y m i c </w>': 1,
#              'e c t a t i c </w>': 12,
#              't o r t u o u s . </w>': 42,
#              'b a s i l a r </w>': 73,
#              'r e t i c u l a r </w>': 4,
#              'h i a t a l </w>': 37,
#              'h e r n i a . </w>': 30,
#              'b a s e </w>': 79,
#              'r e f l e c t </w>': 9,
#              'e p i c a r d i a l </w>': 10,
#              'f a t </w>': 10,
#              'b r e a s t </w>': 14,
#              't i s s u e . </w>': 1,
#              'w i d e n i n g . </w>': 24,
#              'a p p e a r i n g </w>': 28,
#              'd e f o r m i t y </w>': 41,
#              '7 t h </w>': 10,
#              's u g g e s t i v e </w>': 16,
#              'i n j u r y . </w>': 8,
#              'e x p a n d e d . </w>': 104,
#              'i n f i l t r a t e . </w>': 96,
#              'p n e u m o n i a </w>': 40,
#              'a d e n o p a t h y </w>': 48,
#              'n o d u l e s </w>': 119,
#              'm a s s e s . </w>': 81,
#              's i g n i f i c a n t </w>': 37,
#              'c o n g e s t i o n . </w>': 16,
#              't h e y </w>': 3,
#              'r e </w>': 2,
#              'o v o i d </w>': 3,
#              '3 5 </w>': 3,
#              'r e t r o c a r d i a c </w>': 23,
#              'a r e a </w>': 31,
#              'a p </w>': 25,
#              'n o t </w>': 92,
#              'w e l l </w>': 64,
#              'd e d i c a t e d </w>': 2,
#              's c a n </w>': 7,
#              'r e c o m m e n d e d . </w>': 2,
#              'l y m p h a d e n o p a t h y . </w>': 4,
#              'd e s t r u c t i v e </w>': 8,
#              'l e s i o n s . </w>': 3,
#              'p r e s e n t </w>': 133,
#              'm u l t i p l e </w>': 51,
#              'r i b s </w>': 14,
#              'p r e v i o u s </w>': 61,
#              's c o l i o s i s </w>': 24,
#              'c o n s o l i d a t i o n s </w>': 14,
#              's u g g e s t </w>': 85,
#              'h a s </w>': 79,
#              'b e e n </w>': 54,
#              'r e s o l u t i o n </w>': 5,
#              'c r o w d i n g . </w>': 31,
#              'd i s c r e t e </w>': 8,
#              'h e m i d i a p h r a g m </w>': 43,
#              'p i c c </w>': 21,
#              'm i d </w>': 54,
#              's v c </w>': 5,
#              'f e e d i n g </w>': 4,
#              'c o u r s e s </w>': 3,
#              'b e l o w </w>': 8,
#              'd i a p h r a g m . </w>': 51,
#              's i g n i f i c a n t l y </w>': 23,
#              'e n l a r g e d . </w>': 113,
#              'a r t h r i t i c </w>': 29,
#              'f e w </w>': 10,
#              's p e c i f i c a l l y </w>': 80,
#              'c a r d i o </w>': 69,
#              's t o m a c h </w>': 7,
#              'e l e v a t i o n . </w>': 3,
#              'r e p r e s e n t i n g </w>': 20,
#              's t u d y </w>': 22,
#              'l i m i t e d </w>': 37,
#              'b y </w>': 23,
#              'b o d y </w>': 37,
#              'h a b i t u s . </w>': 7,
#              'p r o m i n e n c e </w>': 34,
#              'c o a r s e n e d </w>': 4,
#              'm a r k i n g s </w>': 49,
#              'd e v e l o p i n g </w>': 4,
#              'a b n o r m a l i t y </w>': 32,
#              'p l e u r a </w>': 5,
#              'd e m o n s t r a t e s </w>': 8,
#              'd i s c </w>': 27,
#              't h o r a c o l u m b a r </w>': 36,
#              'a s </w>': 44,
#              'c a r d i o m e g a l y . </w>': 81,
#              'n e g a t i v e </w>': 109,
#              't e c h n i q u e . </w>': 8,
#              'v i s i b l e </w>': 138,
#              'h y p o i n f l a t e d </w>': 22,
#              'b u t </w>': 47,
#              'd u e </w>': 29,
#              'v o l u m e </w>': 16,
#              'o v e r l o a d . </w>': 1,
#              'r e s i d u a l </w>': 12,
#              't u n n e l e d </w>': 4,
#              'd i a l y s i s </w>': 4,
#              'o s t e o p e n i a </w>': 9,
#              'e k g </w>': 1,
#              'l e a d s . </w>': 4,
#              'm a y </w>': 90,
#              'b e </w>': 81,
#              'p a r t i a l l y </w>': 17,
#              's </w>': 22,
#              'k n o w n </w>': 8,
#              't h y r o i d </w>': 1,
#              'm a s s . </w>': 3,
#              'o p a c i f i c a t i o n . </w>': 6,
#              's c o l i o t i c </w>': 4,
#              'g i v e n </w>': 11,
#              'o v e r l a p p i n g </w>': 5,
#              't i s s u e </w>': 45,
#              's i l h o u e t t e s . </w>': 5,
#              'h y p e r e x p a n s i o n </w>': 16,
#              'l o c u l a t e d . </w>': 2,
#              's c l e r o t i c </w>': 6,
#              'l e s i o n </w>': 9,
#              'p r o x i m a l </w>': 11,
#              'c l a v i c l e . </w>': 7,
#              'h a v e </w>': 75,
#              'i n t e r v a l . </w>': 66,
#              'm i d d l e </w>': 33,
#              'l o b e . </w>': 91,
#              'i n f e r i o r </w>': 11,
#              'e x c l u d e d . </w>': 8,
#              'b a c k g r o u n d </w>': 4,
#              'm a r k e d </w>': 14,
#              'c e n t r i l o b u l a r </w>': 1,
#              's t r e a k y </w>': 55,
#              'a p p e a r a n c e </w>': 59,
#              'c a r d i a </w>': 4,
#              'k n e e </w>': 5,
#              's e v e r e </w>': 23,
#              't r i c o m p a r t m e n t a l </w>': 1,
#              'o b l i t e r a t i o n </w>': 2,
#              'j o i n t </w>': 15,
#              's p a c e s . </w>': 1,
#              'd i s l o c a t i o n . </w>': 7,
#              'm e d i a l </w>': 23,
#              'c o m p a r t m e n t . </w>': 1,
#              'e v a l u a t i o n </w>': 23,
#              'p a t e l l o f e m o r a l </w>': 1,
#              's p a c e . </w>': 4,
#              't o p </w>': 18,
#              'c a l c i f i c a t i o n . </w>': 18,
#              'n o n </w>': 3,
#              'e v e n t r a t i o n </w>': 22,
#              'i d e n t i f i e d </w>': 42,
#              'p r e v i o u s l y </w>': 17,
#              'l a r g e l y </w>': 2,
#              's i n c e </w>': 21,
#              'c o m p u t e d </w>': 1,
#              't o m o g r a m . </w>': 1,
#              'h y p e r i n f l a t i o n </w>': 18,
#              'c o m p a r i s o n . </w>': 6,
#              'i c d </w>': 11,
#              'p a c e m a k e r . </w>': 3,
#              'o v e r a l l </w>': 16,
#              'a p e x . </w>': 13,
#              'd e m o n s t r a t e d </w>': 20,
#              'l o r d o t i c </w>': 6,
#              'c o n s i d e r i n g </w>': 5,
#              'd i f f e r e n c e s </w>': 4,
#              't e c h n i c a l </w>': 8,
#              'f a c t o r s </w>': 8,
#              'd e n s e </w>': 20,
#              's u g g e s t s </w>': 9,
#              'p r o c e s s . </w>': 20,
#              'w a s </w>': 36,
#              'o b t a i n e d </w>': 5,
#              'c o n d i t i o n . </w>': 1,
#              'g r e a t e r </w>': 31,
#              'l e f t . </w>': 24,
#              'r e g i o n . </w>': 13,
#              'c a r d i o t h o r a c i c </w>': 1,
#              'r a t i o </w>': 1,
#              '1 6 </w>': 4,
#              't w o 2 4 </w>': 1,
#              'c o a r s e </w>': 7,
#              'p e r i h i l a r </w>': 30,
#              'p r e d o m i n a n c e . </w>': 1,
#              't h a n </w>': 41,
#              'l a r g e r </w>': 3,
#              'c a l c i f i c a t i o n </w>': 36,
#              'i n v o l v i n g </w>': 12,
#              'a b d o m i n a l </w>': 10,
#              'p a </w>': 36,
#              's u p e r i m p o s e d </w>': 15,
#              's t r u c t u r e s . </w>': 7,
#              'f i r s t </w>': 9,
#              'c o s t i c a r t i l a g e </w>': 2,
#              'j u n c t i o n </w>': 5,
#              'c o n t r i b u t e s </w>': 1,
#              'e l e c t r o n i c </w>': 3,
#              'd e v i c e </w>': 13,
#              'h e a r t . </w>': 31,
#              'c h a n g e s . </w>': 33,
#              'v i e w s . </w>': 3,
#              'a f t e r </w>': 1,
#              'c i r r h o t i c </w>': 1,
#              'r e t r o s t e r n a l </w>': 12,
#              'f a v o r e d </w>': 3,
#              'o s t e o p h y t e s </w>': 14,
#              'a s p e c t </w>': 11,
#              's t a b l e . </w>': 106,
#              'p r o b a b l e </w>': 16,
#              'o p a c i t y . </w>': 75,
#              'f o r e i g n </w>': 12,
#              'i n d i c a t e </w>': 8,
#              'w i d e n i n g </w>': 11,
#              'c h a r a c t e r i s t i c </w>': 4,
#              'i n j u r y </w>': 6,
#              'h y p e r l u c e n c y </w>': 4,
#              'f l a t t e n i n g </w>': 29,
#              'e m p h y s e m a t o u s </w>': 25,
#              'p o s t o p e r a t i v e </w>': 12,
#              't h o r a c o t o m y </w>': 3,
#              'l o b e c t o m y . </w>': 3,
#              'm a s s </w>': 21,
#              'c a l i b e r . </w>': 10,
#              'r a d i o g r a p h . </w>': 6,
#              's t e n t </w>': 5,
#              'g r a f t </w>': 4,
#              'o v e r l i e s </w>': 10,
#              'r e m a i n s </w>': 30,
#              'e l e v a t e d . </w>': 11,
#              'i n d i s t i n c t </w>': 6,
#              'm a r g i n a t i o n . </w>': 5,
#              'a c c o u n t i n g </w>': 2,
#              'l o w . </w>': 27,
#              'w e r e </w>': 31,
#              'o b t a i n e d . </w>': 43,
#              'c o n f i g u r a t i o n . </w>': 25,
#              'a e r a t e d . </w>': 25,
#              'e n l a r g e m e n t . </w>': 9,
#              's o m e </w>': 34,
#              'r e l a t e s </w>': 1,
#              '1 9 </w>': 4,
#              'i n t e r r u p t i o n </w>': 1,
#              'l e v e l </w>': 12,
#              'o v e r l a p </w>': 5,
#              'c l a v i c l e </w>': 23,
#              'a z y g o s </w>': 7,
#              'v e i n . </w>': 8,
#              'd e n s i t i e s . </w>': 2,
#              's t a t u s </w>': 17,
#              'p o s t </w>': 22,
#              'c a b g . </w>': 20,
#              's t e n t . </w>': 7,
#              'v a s c u l a r i t y . </w>': 38,
#              'e p i g a s t r i u m </w>': 1,
#              'a b d o m e n . </w>': 17,
#              's u g g e s t i n g </w>': 21,
#              't w o </w>': 12,
#              't u b e s </w>': 2,
#              'p r i o r . </w>': 15,
#              'i m p r o v e m e n t </w>': 8,
#              'f l u i d . </w>': 34,
#              'e n d o t r a c h e a l </w>': 3,
#              'a p p r o x i m a t e l y </w>': 22,
#              '4 5 </w>': 2,
#              'i n t e r n a l </w>': 8,
#              'j u g u l a r </w>': 8,
#              'a p p r o x i m a t i n g </w>': 3,
#              'h i g h </w>': 4,
#              's v c . </w>': 31,
#              's e q u e l a </w>': 18,
#              'c o n s o l i d a t i n g </w>': 5,
#              'e n g o r g e d . </w>': 8,
#              'i n f i l t r a t e s . </w>': 67,
#              'm i d l u n g . </w>': 21,
#              'b o r d e r l i n e </w>': 30,
#              't o r t u r o u s </w>': 2,
#              'b e t t e r </w>': 6,
#              's h o u l d e r </w>': 9,
#              'd a t e d </w>': 3,
#              'l u c e n c y </w>': 19,
#              'b e n i g n . </w>': 1,
#              'j o i n t s . </w>': 3,
#              'r o t a t e d </w>': 9,
#              'q u e s t i o n </w>': 6,
#              'e n l a r g e m e n t </w>': 20,
#              'a p p r e c i a t e d </w>': 5,
#              'l o b e s . </w>': 15,
#              'c h a n g e . </w>': 13,
#              's i m i l a r </w>': 25,
#              'e x a m s . </w>': 3,
#              'f u s i o n </w>': 13,
#              'd i s h </w>': 4,
#              'c a l c i f i c a t i o n s . </w>': 21,
#              'n o d u l a r </w>': 50,
#              'o v e r </w>': 66,
#              'f i f t h </w>': 3,
#              's i x </w>': 1,
#              't h i c k e n i n g . </w>': 13,
#              'h u m e r a l </w>': 16,
#              'p r o s t h e s i s </w>': 3,
#              'i n c o m p l e t e l y </w>': 8,
#              'e v a l u a t e d . </w>': 4,
#              'e v a l u a t e d </w>': 5,
#              'b i l a t e r a l l y </w>': 42,
#              'r o t a t e d . </w>': 6,
#              'e l e v a t e d </w>': 14,
#              'c o m p a t i b l e </w>': 46,
#              'a c c e n t u a t e d . </w>': 2,
#              'd i s l o c a t i o n </w>': 4,
#              'h u m e r u s . </w>': 6,
#              'c o r r e l a t e </w>': 8,
#              'c l i n i c a l l y . </w>': 3,
#              'j u x t a h i l a r </w>': 1,
#              'm o d e r a t e </w>': 59,
#              'e t i o l o g y </w>': 3,
#              'd e t e r m i n e d . </w>': 1,
#              'c t </w>': 14,
#              'b e n i g n </w>': 1,
#              'e t i o l o g y . </w>': 1,
#              'a l i g n m e n t . </w>': 3,
#              'p r o b a b l y </w>': 9,
#              'm o s t l y </w>': 1,
#              'd i f f i c u l t </w>': 1,
#              'c o m p l e t e l y </w>': 1,
#              'e x c l u d e </w>': 3,
#              'e x t e n s i v e </w>': 10,
#              's u p r a h i l a r </w>': 6,
#              'w h o s e </w>': 3,
#              'a p p e a r a n c e s </w>': 1,
#              'm e t a s t a t i c </w>': 3,
#              'x </w>': 12,
#              '2 1 </w>': 2,
#              '6 t h </w>': 12,
#              '1 2 </w>': 5,
#              'i n t e r s p a c e </w>': 2,
#              '5 t h </w>': 10,
#              'r i g h t . </w>': 13,
#              '1 1 </w>': 2,
#              'i n t e r s p a c e s </w>': 1,
#              'i f </w>': 4,
#              'a l r e a d y </w>': 2,
#              'p e r f o r m e d </w>': 5,
#              'c o n t r a s t </w>': 11,
#              'e n h a n c e d </w>': 1,
#              'w o u l d </w>': 6,
#              's u i t e d </w>': 1,
#              'e v a l u a t e </w>': 3,
#              't h e s e </w>': 19,
#              'a x i l l a r y </w>': 9,
#              'a t r i u m . </w>': 13,
#              'r e c e s s </w>': 4,
#              'c o n f l u e n t </w>': 7,
#              'p o s t e r i o r l y . </w>': 2,
#              'b i a p i c a l </w>': 25,
#              's t u d y . </w>': 29,
#              'e c t a t i c . </w>': 6,
#              'p a r e n c h y m a l </w>': 15,
#              'b a s e . </w>': 57,
#              'b l u n t e d . </w>': 6,
#              'h e a l e d . </w>': 1,
#              'h e r n i a </w>': 15,
#              's t e r n o t o m y . </w>': 13,
#              'b l u n t i n g . </w>': 3,
#              'u n d e r g o n e </w>': 1,
#              'm a r k i n g s . </w>': 13,
#              'b u l l o u s </w>': 4,
#              'f o u n d </w>': 1,
#              't h o r a x . </w>': 6,
#              'f u l l n e s s </w>': 4,
#              'h i l u m </w>': 10,
#              'p r o g r e s s i o n </w>': 1,
#              'r e t r o h i l a r </w>': 1,
#              's c a n . </w>': 4,
#              'f o u n d . </w>': 1,
#              'v a g u e </w>': 15,
#              'r e l a t e d </w>': 14,
#              's c a p u l a r </w>': 1,
#              'h y p e r i n f l a t e d </w>': 32,
#              'd i a m e t e r </w>': 8,
#              'l e s i o n . </w>': 2,
#              'd e v e l o p e d </w>': 9,
#              'd e f o r m i t i e s </w>': 19,
#              'c o m p o n e n t </w>': 1,
#              'c o r r e s p o n d s </w>': 2,
#              'o n e </w>': 14,
#              'p r o j e c t e d </w>': 8,
#              'p o s i t i o n i n g </w>': 3,
#              'p a c e m a k e r </w>': 18,
#              'i t s </w>': 7,
#              't h r e e l e a d s </w>': 1,
#              'a d d i t i o n a l </w>': 4,
#              'p a c i n g </w>': 4,
#              'a l s o </w>': 41,
#              'm i n i m a l l y </w>': 4,
#              'b a s e s . </w>': 17,
#              'd e x t r o </w>': 5,
#              'p o s i t i o n a l . </w>': 3,
#              's t u d i e s . </w>': 3,
#              't 9 </w>': 6,
#              'w o r s e </w>': 4,
#              'b l u n t e d </w>': 7,
#              's u b c l a v i a n </w>': 14,
#              'p o s t e r i o r l y </w>': 4,
#              'p o s t s u r g i c a l </w>': 29,
#              'f u s i o n . </w>': 6,
#              't 4 </w>': 1,
#              't 7 </w>': 2,
#              't o r t u o s i t y . </w>': 12,
#              'e x t e r n a l </w>': 14,
#              'm o n i t o r </w>': 12,
#              'a i r w a y s . </w>': 5,
#              'i n c i d e n t a l </w>': 4,
#              'n o t e </w>': 10,
#              'd i a p h r a g m </w>': 18,
#              'a i r s p a c e . </w>': 6,
#              'i r r e g u l a r </w>': 10,
#              'p e r s i s t e n t </w>': 21,
#              'd e x t r o s c o l i o s i s </w>': 13,
#              'i m a g i n g . </w>': 2,
#              'h e a d </w>': 7,
#              'a n c h o r s . </w>': 1,
#              'k y p h o s i s </w>': 9,
#              'd i m e n s i o n </w>': 2,
#              '3 r d </w>': 2,
#              '4 t h </w>': 4,
#              'b e y o n d </w>': 1,
#              's k i n </w>': 3,
#              'f o l d </w>': 1,
#              'a r t i f a c t . </w>': 7,
#              'e c t a s i a </w>': 19,
#              'i r r e g u l a r i t y </w>': 9,
#              'i n d e t e r m i n a t e </w>': 8,
#              'd e f o r m i t i e s . </w>': 6,
#              's t e n t s </w>': 2,
#              'v i s u a l i z e d . </w>': 9,
#              'g r e a t e s t </w>': 5,
#              'i n c l u d i n g </w>': 5,
#              'p r o j e c t i o n . </w>': 13,
#              'e a r l y </w>': 6,
#              'i v c </w>': 3,
#              'p r o c e d u r e . </w>': 5,
#              'a r t e r i e s . </w>': 6,
#              'a s s o c i a t e d </w>': 16,
#              'p o s i t i o n . </w>': 17,
#              'a r i s i n g </w>': 1,
#              'o p a c i f i c a t i o n </w>': 9,
#              'l e v o c u r v a t u r e </w>': 4,
#              's h a p e d </w>': 5,
#              's c o l i o s i s . </w>': 5,
#              'l e v o s c o l i o s i s </w>': 9,
#              'p e r i t r a c h e a l </w>': 1,
#              'h y p o i n f l a t e d . </w>': 12,
#              'd e c r e a s e d </w>': 11,
#              'p e r i p h e r a l </w>': 11,
#              'a b n o r m a l </w>': 10,
#              'd e m o n s t r a t e </w>': 30,
#              'i n f r a h i l a r </w>': 6,
#              '9 </w>': 3,
#              's h i e l d e d . </w>': 2,
#              'd e c r e a s e d . </w>': 3,
#              'd i s c o i d </w>': 3,
#              'v a s c u l a t u r i t y </w>': 1,
#              'i n c r e a s e d . </w>': 3,
#              'u n d e r l y i n g </w>': 8,
#              'c o m p r e s s i v e </w>': 2,
#              's i z e d </w>': 11,
#              'o s t e o p h y t e </w>': 9,
#              'f o r m a t i o n </w>': 8,
#              'h o w e v e r </w>': 15,
#              'd e g e n e r a t i o n </w>': 2,
#              'z o n e </w>': 9,
#              'l i n e </w>': 22,
#              'g r a n u l o m a t a </w>': 3,
#              'b o d i e s </w>': 13,
#              'o v e r l a p . </w>': 1,
#              'm a i n t a i n e d . </w>': 5,
#              'f i v e n o n r i b </w>': 1,
#              'b e a r i n g </w>': 1,
#              't y p e </w>': 1,
#              'a l i g n m e n t </w>': 4,
#              'a m o u n t </w>': 14,
#              's t o o l . </w>': 1,
#              'u n r e m a r k a b l e </w>': 40,
#              'a t h e r o s c l e r o s i s </w>': 8,
#              'w o r s e n e d </w>': 1,
#              'p o s s i b l e </w>': 7,
#              'f a t . </w>': 6,
#              'a n y </w>': 30,
#              'u n d e r </w>': 44,
#              'g a s t r o s t o m y </w>': 2,
#              'd i s l o c a t i o n s . </w>': 3,
#              'c o n v e x i t y </w>': 5,
#              't r i a n g u l a r </w>': 1,
#              'm e a s u r i n g </w>': 16,
#              '5 8 </w>': 1,
#              '6 0 </w>': 1,
#              'd i a m e t e r . </w>': 12,
#              'o b s e r v e d </w>': 1,
#              't h i c k e n i n g </w>': 26,
#              'p a r e n c h y m a </w>': 3,
#              'n g </w>': 2,
#              'r e m o v e d . </w>': 8,
#              'o b v i o u s </w>': 4,
#              'n o n d i s p l a c e d </w>': 2,
#              's u t u r e </w>': 5,
#              'm a t e r i a l </w>': 4,
#              's u r g e r y . </w>': 7,
#              's u b s t e r n a l </w>': 1,
#              'r e l a t i v e l y </w>': 4,
#              'c o n g e s t i o n </w>': 11,
#              'e x t r e m i t y </w>': 7,
#              't e r m i n a t e s </w>': 2,
#              'i m p l a n t a b l e </w>': 3,
#              'c o p d . </w>': 4,
#              'd a t i n g </w>': 2,
#              'b a c k </w>': 2,
#              's h a d o w s </w>': 4,
#              'p i e r c i n g s . </w>': 1,
#              'p r o j e c t s </w>': 10,
#              'p r o j e c t i o n </w>': 10,
#              's u b o p t i m a l </w>': 1,
#              'c o u l d </w>': 21,
#              'r a i s e </w>': 1,
#              'l a r g e . </w>': 10,
#              'c l o s u r e </w>': 3,
#              'l u n g . </w>': 28,
#              'a i c d </w>': 4,
#              'p l a c e m e n t . </w>': 4,
#              'o n e i n </w>': 1,
#              'a n o t h e r </w>': 4,
#              'v e n t r i c l e </w>': 9,
#              's t r i p e . </w>': 1,
#              'a c t i v e </w>': 11,
#              'n o n s p e c i f i c </w>': 1,
#              'r e l a t i v e </w>': 8,
#              'l u c e n c i e s </w>': 3,
#              'e m p h y s e m a </w>': 4,
#              's e p t a l </w>': 3,
#              'o c c l u d e r </w>': 2,
#              'c u r v a t u r e . </w>': 2,
#              'c o n s o l i d a t i v e </w>': 5,
#              'r a d i o g r a p h i c </w>': 4,
#              'm i t r a l </w>': 5,
#              'v a l v e </w>': 12,
#              'c o n t i n u e d </w>': 2,
#              'e s p e c i a l l y </w>': 1,
#              'a c c e n t u a t e d </w>': 7,
#              'i n t e r r u p t e d </w>': 1,
#              'c a n n o t </w>': 9,
#              'm a r k i n g . </w>': 1,
#              'a s p e c t . </w>': 1,
#              'd e f i b r i l l a t o r </w>': 7,
#              'n o d e </w>': 3,
#              'a s b e s t o s </w>': 1,
#              'e x p o s u r e . </w>': 2,
#              'b u l l a e </w>': 5,
#              'i n t e r l o b a r </w>': 1,
#              'f i s s u r a l </w>': 3,
#              'r e c e s s e s </w>': 1,
#              's c a r . </w>': 6,
#              'm i d t h o r a c i c </w>': 20,
#              'g r o s s </w>': 6,
#              'c o l l e c t i o n </w>': 6,
#              'r e p l a c e m e n t . </w>': 6,
#              'k n e e . </w>': 2,
#              't o t a l </w>': 2,
#              'c o m p a r t m e n t </w>': 2,
#              'm a r k e d l y </w>': 3,
#              'n a r r o w . </w>': 1,
#              'f e m u r </w>': 5,
#              't i b i a l </w>': 1,
#              'p l a t e a u s . </w>': 1,
#              'c a v i t a r y </w>': 11,
#              'm a s t e c t o m y . </w>': 4,
#              'f i b r o s i s . </w>': 6,
#              'r e g i o n </w>': 21,
#              '2 </w>': 3,
#              'v e r s u s </w>': 29,
#              't h r e e </w>': 3,
#              'l a r g e s t </w>': 2,
#              'm e a s u r e s </w>': 10,
#              'h i l u m . </w>': 8,
#              'i t </w>': 10,
#              'o t h e r </w>': 8,
#              's t i m u l a t o r </w>': 5,
#              'm i d l i n e </w>': 14,
#              't r a c h e a . </w>': 4,
#              'c l a v i c l e s </w>': 1,
#              'e v a l u a t i o n . </w>': 6,
#              'u n f o l d i n g </w>': 8,
#              's u t u r e s </w>': 5,
#              'b y p a s s </w>': 6,
#              'c r o w d e d </w>': 2,
#              'o v e r t </w>': 8,
#              'a r t i f a c t </w>': 6,
#              'r e l a t i n g </w>': 1,
#              'v e n a </w>': 1,
#              'd e f i n i t i v e </w>': 1,
#              't r a n s m e t a t a r s a l </w>': 1,
#              'a m p u t a t i o n . </w>': 2,
#              'e r o s i o n s </w>': 1,
#              'i n f e c t i o n s . </w>': 1,
#              'a p i c e s </w>': 6,
#              'o b s c u r e </w>': 5,
#              'e n d . </w>': 1,
#              's i n g l e </w>': 6,
#              'c a r d i o p u l m o n a r y </w>': 7,
#              'f o c u s </w>': 2,
#              't h i n </w>': 4,
#              'l i n g u l a r </w>': 6,
#              's c a r </w>': 15,
#              'm a s s l i k e </w>': 3,
#              'c a u d a l </w>': 1,
#              'f r a c t u r e d . </w>': 2,
#              'r e c t a l </w>': 1,
#              'b a l l o o n </w>': 1,
#              'b o c h d a l e k </w>': 2,
#              't w o i c d </w>': 1,
#              'e x p e c t e d </w>': 11,
#              'p r o s t h e s e s </w>': 2,
#              'm e d i a s t i n u m . t h e r e </w>': 1,
#              'w e d g e </w>': 10,
#              't 1 2 . </w>': 4,
#              'r e c u r r e n c e </w>': 1,
#              's t r i n g y </w>': 1,
#              'p o s t t r a u m a t i c </w>': 5,
#              'v e r t e r b r o p l a s t y </w>': 2,
#              ...})

# %%
def get_pair_counts(vocab):
    pair_counts = defaultdict(int)
    for k, v in vocab.items():
        chars = k.split()
        for i in range(len(chars)-1):
            pair_counts[(chars[i], chars[i+1])]+=1
    return pair_counts

# %%
char_pair_counts = get_pair_counts(vocab)
char_pair_counts
# Out:
# defaultdict(int,
#             {('t', 'h'): 109,
#              ('h', 'e'): 72,
#              ('e', '</w>'): 197,
#              ('l', 'u'): 53,
#              ('u', 'n'): 48,
#              ('n', 'g'): 135,
#              ('g', 's'): 7,
#              ('s', '</w>'): 207,
#              ('r', 'e'): 227,
#              ('e', 'm'): 69,
#              ('m', 'a'): 111,
#              ('a', 'i'): 30,
#              ('i', 'n'): 307,
#              ('n', '</w>'): 117,
#              ('h', 'y'): 47,
#              ('y', 'p'): 30,
#              ('p', 'e'): 87,
#              ('e', 'r'): 262,
#              ('e', 'x'): 46,
#              ('x', 'p'): 10,
#              ('p', 'a'): 76,
#              ('a', 'n'): 79,
#              ('n', 'd'): 69,
#              ('d', 'e'): 138,
#              ('e', 'd'): 208,
#              ('d', '.'): 66,
#              ('.', '</w>'): 513,
#              ('n', 'o'): 61,
#              ('o', '</w>'): 10,
#              ('a', 's'): 96,
#              ('s', 's'): 54,
#              ('s', 'e'): 97,
#              ('e', 's'): 190,
#              ('o', 'r'): 139,
#              ('r', '</w>'): 100,
#              ('n', 'f'): 37,
#              ('f', 'i'): 61,
#              ('i', 'l'): 65,
#              ('l', 't'): 14,
#              ('t', 'r'): 111,
#              ('r', 'a'): 206,
#              ('a', 't'): 263,
#              ('t', 'e'): 255,
#              ('s', '.'): 121,
#              ('p', 'l'): 44,
#              ('l', 'e'): 126,
#              ('e', 'u'): 23,
#              ('u', 'r'): 84,
#              ('a', 'l'): 240,
#              ('l', '</w>'): 141,
#              ('m', 'e'): 91,
#              ('d', 'i'): 129,
#              ('i', 'a'): 79,
#              ('s', 't'): 179,
#              ('t', 'i'): 295,
#              ('n', 'a'): 56,
#              ('i', 'r'): 24,
#              ('c', 'o'): 109,
#              ('o', 'l'): 65,
#              ('l', 'l'): 74,
#              ('e', 'c'): 84,
#              ('c', 't'): 102,
#              ('i', 'o'): 211,
#              ('o', 'n'): 289,
#              ('n', 's'): 75,
#              ('e', 'a'): 76,
#              ('a', 'r'): 211,
#              ('r', 't'): 73,
#              ('t', '</w>'): 102,
#              ('s', 'i'): 128,
#              ('i', 'z'): 16,
#              ('z', 'e'): 9,
#              ('r', 'm'): 33,
#              ('l', '.'): 17,
#              ('i', 's'): 109,
#              ('e', '.'): 59,
#              ('n', 'u'): 27,
#              ('u', 'm'): 60,
#              ('m', '</w>'): 28,
#              ('n', 'r'): 3,
#              ('r', 'k'): 10,
#              ('k', 'a'): 3,
#              ('a', 'b'): 41,
#              ('b', 'l'): 35,
#              ('a', '</w>'): 28,
#              ('t', 'o'): 72,
#              ('t', 'u'): 59,
#              ('u', 'o'): 5,
#              ('o', 'u'): 65,
#              ('u', 's'): 58,
#              ('c', 'a'): 124,
#              ('l', 'c'): 17,
#              ('c', 'i'): 49,
#              ('i', 'f'): 43,
#              ('i', 'e'): 44,
#              ('d', '</w>'): 163,
#              ('h', 'o'): 63,
#              ('a', 'c'): 106,
#              ('i', 'c'): 151,
#              ('c', '</w>'): 67,
#              ('a', 'o'): 5,
#              ('t', 'a'): 75,
#              ('p', 'r'): 63,
#              ('e', 'n'): 213,
#              ('n', 't'): 162,
#              ('t', '.'): 37,
#              ('w', 'i'): 16,
#              ('i', 't'): 99,
#              ('h', '</w>'): 24,
#              ('m', 'p'): 39,
#              ('p', 'h'): 52,
#              ('y', 's'): 16,
#              ('a', '.'): 18,
#              ('e', 'f'): 28,
#              ('f', 'f'): 11,
#              ('f', 'u'): 15,
#              ('p', 'n'): 14,
#              ('n', 'e'): 93,
#              ('m', 'o'): 55,
#              ('o', 't'): 57,
#              ('a', 'x'): 13,
#              ('x', '</w>'): 10,
#              ('f', 'o'): 42,
#              ('o', 'c'): 33,
#              ('r', 's'): 39,
#              ('s', 'p'): 43,
#              ('c', 'e'): 94,
#              ('c', 'l'): 46,
#              ('b', 'i'): 23,
#              ('l', 'a'): 173,
#              ('l', 'y'): 92,
#              ('y', '.'): 42,
#              ('r', 'd'): 31,
#              ('l', 'h'): 4,
#              ('u', 'e'): 28,
#              ('e', 't'): 57,
#              ('t', 't'): 19,
#              ('p', 'u'): 12,
#              ('u', 'l'): 97,
#              ('l', 'm'): 5,
#              ('r', 'y'): 30,
#              ('y', '</w>'): 142,
#              ('v', 'a'): 35,
#              ('s', 'c'): 55,
#              ('c', 'u'): 54,
#              ('n', '.'): 61,
#              ('u', 't'): 24,
#              ('b', 'o'): 18,
#              ('n', 'y'): 3,
#              ('b', 'n'): 6,
#              ('l', 'i'): 91,
#              ('t', 'y'): 30,
#              ('o', 'm'): 77,
#              ('h', 'i'): 47,
#              ('i', 'm'): 54,
#              ('m', 'i'): 70,
#              ('t', 's'): 27,
#              ('r', '.'): 17,
#              ('r', 'i'): 133,
#              ('i', 'g'): 23,
#              ('g', 'h'): 13,
#              ('h', 't'): 7,
#              ('l', 'o'): 73,
#              ('o', 'w'): 30,
#              ('w', 'e'): 14,
#              ('o', 'b'): 35,
#              ('b', 'e'): 36,
#              ('g', 'r'): 29,
#              ('f', 'l'): 26,
#              ('e', 'v'): 50,
#              ('v', 'i'): 49,
#              ('i', 'd'): 66,
#              ('n', 'c'): 68,
#              ('o', 'f'): 3,
#              ('f', '</w>'): 3,
#              ('x', '.'): 6,
#              ('e', 'g'): 22,
#              ('g', 'e'): 63,
#              ('i', 'v'): 26,
#              ('v', 'e'): 105,
#              ('c', 'h'): 56,
#              ('h', 'a'): 38,
#              ('p', 'i'): 32,
#              ('e', 'l'): 69,
#              ('f', 't'): 12,
#              ('a', 'p'): 59,
#              ('h', 'r'): 33,
#              ('a', 'g'): 46,
#              ('g', 'm'): 17,
#              ('m', '.'): 19,
#              ('u', 'i'): 3,
#              ('p', 'p'): 18,
#              ('c', 'y'): 8,
#              ('m', 'y'): 15,
#              ('i', 'p'): 17,
#              ('p', 's'): 11,
#              ('u', 'p'): 20,
#              ('q', 'u'): 15,
#              ('u', 'a'): 23,
#              ('a', 'd'): 39,
#              ('d', 'r'): 12,
#              ('f', 'r'): 15,
#              ('r', 'o'): 132,
#              ('e', 'w'): 12,
#              ('w', 's'): 5,
#              ('s', 'h'): 25,
#              ('w', '</w>'): 11,
#              ('g', 'u'): 15,
#              ('r', 'w'): 5,
#              ('w', 'a'): 12,
#              ('a', 'y'): 8,
#              ('g', '</w>'): 88,
#              ('v', 'o'): 12,
#              ('s', 'u'): 73,
#              ('r', 'g'): 27,
#              ('g', 'i'): 22,
#              ('r', 'h'): 3,
#              ('s', 'o'): 27,
#              ('d', 'a'): 14,
#              ('d', 'p'): 2,
#              ('o', 'v'): 31,
#              ('r', 'l'): 24,
#              ('o', 's'): 113,
#              ('e', 'o'): 23,
#              ('l', 'd'): 17,
#              ('d', 'l'): 10,
#              ('o', 'd'): 26,
#              ('n', 'l'): 9,
#              ('p', '</w>'): 10,
#              ('d', 'u'): 17,
#              ('a', 'v'): 25,
#              ('j', 'u'): 6,
#              ('e', 'p'): 24,
#              ('z', 'a'): 6,
#              ('n', 'i'): 62,
#              ('l', 'v'): 13,
#              ('r', 'v'): 12,
#              ('o', 'p'): 62,
#              ('b', 's'): 16,
#              ('m', 's'): 10,
#              ('s', 'l'): 11,
#              ('t', 'l'): 9,
#              ('x', 'a'): 11,
#              ('a', 'm'): 17,
#              ('i', 'b'): 30,
#              ('b', '</w>'): 4,
#              ('g', 'a'): 18,
#              ('t', 'w'): 16,
#              ('w', 'o'): 19,
#              ('o', 'i'): 18,
#              ('g', 'o'): 8,
#              ('n', 'v'): 5,
#              ('m', 'u'): 8,
#              ('r', 'u'): 20,
#              ('u', 'c'): 21,
#              ('b', 'u'): 17,
#              ('p', 'o'): 51,
#              ('y', 'm'): 12,
#              ('g', 'g'): 8,
#              ('k', 'y'): 4,
#              ('c', '.'): 12,
#              ('e', 'b'): 10,
#              ('b', 'r'): 30,
#              ('s', 'k'): 3,
#              ('k', 'e'): 16,
#              ('e', 'e'): 18,
#              ('a', 'e'): 9,
#              ('t', '5'): 1,
#              ('5', '</w>'): 6,
#              ('m', 'b'): 8,
#              ('b', 'a'): 23,
#              ('l', '2'): 2,
#              ('2', '</w>'): 6,
#              ('u', 'g'): 13,
#              ('d', 'v'): 1,
#              ('p', 'd'): 2,
#              ('i', 'k'): 5,
#              ('z', 'o'): 5,
#              ('r', 'r'): 25,
#              ('u', 'b'): 27,
#              ('y', 't'): 8,
#              ('w', 'h'): 4,
#              ('k', 'i'): 9,
#              ('9', 't'): 1,
#              ('b', '.'): 3,
#              ('c', 'r'): 24,
#              ('b', 'p'): 2,
#              ('x', 't'): 14,
#              ('y', 'i'): 4,
#              ('s', 'm'): 13,
#              ('e', 'q'): 3,
#              ('l', 's'): 8,
#              ('d', 's'): 11,
#              ('i', 'u'): 6,
#              ('d', 'y'): 11,
#              ('y', 'l'): 3,
#              ('4', '</w>'): 5,
#              ('m', 'm'): 14,
#              ('r', 'n'): 16,
#              ('t', 'c'): 1,
#              ('o', 'g'): 17,
#              ('h', 's'): 3,
#              ('x', 'c'): 6,
#              ('u', 'd'): 12,
#              ('w', '.'): 5,
#              ('b', 'd'): 6,
#              ('d', 'o'): 16,
#              ('1', '0'): 4,
#              ('0', '</w>'): 6,
#              ('o', 'j'): 7,
#              ('j', 'e'): 9,
#              ('0', 't'): 1,
#              ('w', 'd'): 3,
#              ('o', 'a'): 7,
#              ('u', 'f'): 2,
#              ('g', '.'): 20,
#              ('c', 'm'): 3,
#              ('s', 'y'): 9,
#              ('f', 'a'): 16,
#              ('7', 't'): 1,
#              ('n', 'j'): 3,
#              ('g', 'n'): 14,
#              ('e', 'y'): 4,
#              ('3', '5'): 1,
#              ('c', 'c'): 10,
#              ('s', 'v'): 3,
#              ('v', 'c'): 3,
#              ('f', 'e'): 16,
#              ('b', 'y'): 2,
#              ('h', 'n'): 3,
#              ('i', 'q'): 5,
#              ('n', 'n'): 8,
#              ('e', 'k'): 2,
#              ('k', 'g'): 2,
#              ('k', 'n'): 5,
#              ('w', 'n'): 2,
#              ('y', 'r'): 1,
#              ('o', 'x'): 3,
#              ('x', 'i'): 10,
#              ('d', 'd'): 4,
#              ('c', 'k'): 10,
#              ('a', 'k'): 6,
#              ('t', 'm'): 3,
#              ('j', 'o'): 4,
#              ('c', 'd'): 5,
#              ('b', 't'): 3,
#              ('1', '6'): 1,
#              ('6', '</w>'): 5,
#              ('o', '2'): 1,
#              ('2', '4'): 1,
#              ('i', 'h'): 2,
#              ('a', 'f'): 5,
#              ('e', 'i'): 7,
#              ('h', '.'): 5,
#              ('1', '9'): 1,
#              ('9', '</w>'): 5,
#              ('p', 't'): 9,
#              ('a', 'z'): 2,
#              ('z', 'y'): 1,
#              ('y', 'g'): 1,
#              ('b', 'g'): 2,
#              ('4', '5'): 1,
#              ('i', 'x'): 4,
#              ('h', 'u'): 6,
#              ('u', 'x'): 2,
#              ('a', 'h'): 4,
#              ('g', 'y'): 4,
#              ('n', 'm'): 3,
#              ('2', '1'): 1,
#              ('1', '</w>'): 7,
#              ('6', 't'): 1,
#              ('1', '2'): 4,
#              ('5', 't'): 1,
#              ('1', '1'): 2,
#              ('l', 'r'): 2,
#              ('r', 'f'): 5,
#              ('n', 'h'): 1,
#              ('l', 'n'): 1,
#              ('o', 'h'): 2,
#              ('t', '9'): 1,
#              ('b', 'c'): 5,
#              ('t', '4'): 1,
#              ('t', '7'): 2,
#              ('7', '</w>'): 4,
#              ('3', 'r'): 1,
#              ('4', 't'): 1,
#              ('y', 'o'): 2,
#              ('p', '.'): 2,
#              ('o', 'o'): 14,
#              ('5', '8'): 1,
#              ('8', '</w>'): 7,
#              ('6', '0'): 1,
#              ('b', 'v'): 2,
#              ('k', '</w>'): 5,
#              ('r', 'c'): 12,
#              ('s', 'b'): 1,
#              ('d', 't'): 4,
#              ('a', 'u'): 5,
#              ('s', 'a'): 15,
#              ('g', 'l'): 5,
#              ('h', 'd'): 1,
#              ('.', 't'): 4,
#              ('d', 'g'): 4,
#              ('t', '1'): 5,
#              ('2', '.'): 2,
#              ('r', 'b'): 2,
#              ('2', 'n'): 1,
#              ('o', 'e'): 2,
#              ('o', 'k'): 2,
#              ('8', 't'): 1,
#              ('y', 'n'): 4,
#              ('3', '1'): 1,
#              ('1', '7'): 1,
#              ('i', '</w>'): 5,
#              ('y', 'e'): 5,
#              ('2', '0'): 1,
#              ('w', 'u'): 1,
#              ('.', 'h'): 1,
#              ('.', 'm'): 1,
#              ('o', '.'): 1,
#              ('p', 'y'): 2,
#              ('t', 'b'): 1,
#              ('2', 't'): 1,
#              ('r', 'p'): 4,
#              ('s', 'w'): 1,
#              ('3', '3'): 2,
#              ('3', '</w>'): 4,
#              ('s', 'r'): 2,
#              ('i', 'j'): 1,
#              ('j', '</w>'): 1,
#              ('d', 'j'): 1,
#              ('j', 'a'): 1,
#              ('t', '6'): 1,
#              ('t', '8'): 1,
#              ('a', 'q'): 1,
#              ('m', 'l'): 1,
#              ('.', 'c'): 1,
#              ('k', '.'): 1,
#              ('l', '1'): 2,
#              ('p', 'm'): 2,
#              ('0', '.'): 1,
#              ('7', '0'): 1,
#              ('d', 'c'): 1,
#              ('l', 'b'): 1,
#              ('n', 'k'): 3,
#              ('k', 'l'): 2,
#              ('d', 'f'): 2,
#              ('1', '3'): 1,
#              ('2', 'c'): 1,
#              ('1', '4'): 1,
#              ('l', 'p'): 1,
#              ('p', 'f'): 1,
#              ('l', 'g'): 1,
#              ('1', 's'): 1,
#              ('k', 's'): 1,
#              ('2', '2'): 1,
#              ('3', '2'): 1,
#              ('e', 'h'): 1,
#              ('v', '</w>'): 2,
#              ('i', '.'): 2,
#              ('.', 'i'): 1,
#              ('1', '8'): 1,
#              ('v', 'n'): 1,
#              ('7', '.'): 1,
#              ('y', 'd'): 1,
#              ('3', '0'): 1,
#              ('.', 'u'): 1,
#              ('.', 'p'): 1,
#              ('x', 'e'): 1,
#              ('1', '5'): 1,
#              ('2', '6'): 1,
#              ('2', '5'): 1,
#              ('4', '3'): 1,
#              ('2', '8'): 1,
#              ('4', '9'): 1,
#              ('z', 'i'): 1,
#              ('1', 'm'): 1,
#              ('k', 'u'): 2,
#              ('3', '7'): 1,
#              ('5', '9'): 1,
#              ('x', 'u'): 1,
#              ('6', '8'): 1,
#              ('p', 'w'): 2,
#              ('h', 'l'): 1,
#              ('t', 'n'): 1,
#              ('1', '.'): 1,
#              ('3', '8'): 1,
#              ('1', 'a'): 1,
#              ('s', 'f'): 1,
#              ('4', '6'): 1,
#              ('d', 'n'): 1,
#              ('v', 'p'): 1,
#              ('b', 'm'): 1,
#              ('v', 'u'): 1,
#              ('l', '3'): 1,
#              ('3', '.'): 2,
#              ('l', '4'): 1,
#              ('s', '1'): 1})

# %%
def merge_pairs(best_pair, vocab_in):
    vocab_out = {}
    bigram = re.escape(" ".join(best_pair))

    p = re.compile(r'(?<!\S)'+bigram + r'(?!\S)')
    for word in vocab_in:
        w_out = p.sub(''.join(best_pair), word)
  
        vocab_out[w_out] = vocab_in[word]
    return vocab_out

# %%
def get_tokens_count(vocab):
    char_tokens = defaultdict(int)
    
    for word, count in vocab.items():
        tokens = word.split()
        for t in tokens:
            char_tokens[t]+=count
            
    return char_tokens

# %%
tokens = get_tokens_count(vocab)
len(tokens)
# Out:
# 38

# %%
tokens
# Out:
# defaultdict(int,
#             {'t': 43042,
#              'h': 21507,
#              'e': 62845,
#              '</w>': 96024,
#              'l': 34639,
#              'u': 22094,
#              'n': 40834,
#              'g': 8537,
#              's': 35441,
#              'r': 43069,
#              'm': 16900,
#              'a': 54748,
#              'i': 46950,
#              'y': 5400,
#              'p': 14106,
#              'x': 2937,
#              'd': 15578,
#              '.': 14321,
#              'o': 42869,
#              'f': 12699,
#              'c': 19871,
#              'z': 2102,
#              'k': 913,
#              'b': 4953,
#              'w': 3749,
#              'v': 4146,
#              'q': 93,
#              'j': 175,
#              '5': 29,
#              '2': 36,
#              '9': 26,
#              '4': 17,
#              '1': 76,
#              '0': 18,
#              '7': 22,
#              '3': 25,
#              '6': 27,
#              '8': 23})

# %%
import numpy as np

# %%
get_pair_counts(vocab).get('k')

# %%
# %%time
# merge the ch pairs with the max count in bottom-up manner
iters = 1000
for i in range(iters):
    pairs = get_pair_counts(vocab)
    if not pairs:
        break
    best_pair = max(pairs, key = pairs.get)

    vocab = merge_pairs(best_pair, vocab)
#     print(len(get_tokens_count(vocab)))
# Out:
# CPU times: user 4.52 s, sys: 21.3 ms, total: 4.54 s
# Wall time: 4.55 s

# %%
def tokenize_word(string, sorted_tokens, unknown_token='</u>'):
    
    if string == '':
        return []
    if sorted_tokens == []:
        return [unknown_token]

    string_tokens = []
    for i in range(len(sorted_tokens)):
        token = sorted_tokens[i]
        token_reg = re.escape(token.replace('.', '[.]'))

        matched_positions = [(m.start(0), m.end(0)) for m in re.finditer(token_reg, string)]
        if len(matched_positions) == 0:
            continue
        substring_end_positions = [matched_position[0] for matched_position in matched_positions]

        substring_start_position = 0
        for substring_end_position in substring_end_positions:
            substring = string[substring_start_position:substring_end_position]
            string_tokens += tokenize_word(string=substring, sorted_tokens=sorted_tokens[i+1:], unknown_token=unknown_token)
            string_tokens += [token]
            substring_start_position = substring_end_position + len(token)
        remaining_substring = string[substring_start_position:]
        string_tokens += tokenize_word(string=remaining_substring, sorted_tokens=sorted_tokens[i+1:], unknown_token=unknown_token)
        break
    if len(string_tokens)==0:
        string_tokens.append(unknown_token)
    return string_tokens

# %%
def measure_token_length(token):
    if token[-4:] == '</w>':
        return len(token[:-4]) + 1
    else:
        return len(token)

# %%
word_given_known = 'medication</w>'

# %%
token_freqs = get_tokens_count(vocab)
sorted_tokens_tuple = sorted(token_freqs.items(), key=lambda item: (measure_token_length(item[0]), item[1]), reverse=True)
sorted_tokens = [token for (token, freq) in sorted_tokens_tuple]

# %%
#store the tokenization of a word if that word already exist in vocabulary
vocab_tokenization = {''.join(word.split()):word for word in vocab.keys()}
def tokenized_postprocessing(word):
    word_given = word
    if word_given in vocab_tokenization:
   
        tokenised_str = vocab_tokenization[word_given].split()

    else:
 
        tokenised_str = tokenize_word(string=word_given, sorted_tokens=sorted_tokens, unknown_token='</u>')
    return tokenised_str

# %%
vocab
# Out:
# {'the</w>': 5778,
#  'lung s</w>': 1719,
#  'remain </w>': 34,
#  'hyperexpan ded.</w>': 32,
#  'no </w>': 4006,
#  'mas ses</w>': 15,
#  'or</w>': 2183,
#  'infiltr ates</w>': 32,
#  'in</w>': 1320,
#  'lung s.</w>': 80,
#  'pleural</w>': 2246,
#  'mediastinal</w>': 759,
#  'air</w>': 204,
#  'collec tions.</w>': 4,
#  'heart</w>': 1903,
#  'siz e</w>': 1381,
#  'norm al.</w>': 1073,
#  'is</w>': 3977,
#  'norm al</w>': 2097,
#  'siz e.</w>': 355,
#  'mediastin um</w>': 512,
#  'unremark able.</w>': 488,
#  'a</w>': 494,
#  'tortu ous</w>': 69,
#  'calcified</w>': 345,
#  'thoracic</w>': 520,
#  'aort a</w>': 106,
#  'pres ent.</w>': 71,
#  'ar e</w>': 3934,
#  'hyperexpan ded</w>': 47,
#  'consist ent</w>': 83,
#  'wi th</w>': 578,
#  'emphysem a.</w>': 36,
#  'there</w>': 2176,
#  'effu sion</w>': 1070,
#  'pneumothorax</w>': 1127,
#  'focal</w>': 1566,
#  'air space</w>': 741,
#  'dise a se.</w>': 326,
#  'clear</w>': 622,
#  'bilater ally.</w>': 184,
#  'cardiac</w>': 392,
#  'and</w>': 2551,
#  'silhouet tes</w>': 52,
#  'pul monary</w>': 1085,
#  'vasculat ure</w>': 248,
#  'effu sion.</w>': 965,
#  'acute</w>': 610,
#  'b on y</w>': 468,
#  'abnormal ity.</w>': 288,
#  'cardiom ediast inal</w>': 731,
#  'silhouet te</w>': 791,
#  'wi thin</w>': 1386,
#  'limit s</w>': 364,
#  'f or</w>': 320,
#  'contour .</w>': 276,
#  'right</w>': 874,
#  'lower</w>': 225,
#  'lob e</w>': 167,
#  'granulom a</w>': 110,
#  'norm ally</w>': 65,
#  'inflated</w>': 70,
#  'wi thou t</w>': 403,
#  'evid ence</w>': 321,
#  'o f </w>': 2228,
#  'dise ase</w>': 226,
#  'pneumo thorax.</w>': 1058,
#  'degener ative</w>': 427,
#  'chang es</w>': 502,
#  'spin e.</w>': 418,
#  'stable</w>': 464,
#  'elev ation</w>': 37,
#  'left</w>': 751,
#  'hemidiaphragm .</w>': 48,
#  'clear .</w>': 767,
#  'flu id</w>': 24,
#  'appreci ated.</w>': 7,
#  'cholecyst ectomy</w>': 9,
#  'clip s</w>': 67,
#  'no ted</w>': 82,
#  'up per </w>': 316,
#  'quadran t.</w>': 16,
#  'f ron tal</w>': 99,
#  'later al</w>': 275,
#  'view s</w>': 67,
#  'ch est</w>': 196,
#  'sho w</w>': 75,
#  'configura tion</w>': 19,
#  'silhouet te.</w>': 106,
#  'contour </w>': 193,
#  'centr al</w>': 96,
#  'airway s</w>': 17,
#  'lung</w>': 559,
#  'volum es.</w>': 91,
#  'quadran t</w>': 10,
#  'surgical</w>': 77,
#  'per h ap s</w>': 3,
#  'f ro m</w>': 97,
#  'cholecyst ectomy.</w>': 7,
#  'consolid ation</w>': 601,
#  'endplat e</w>': 26,
#  'overli e</w>': 10,
#  'b one</w>': 65,
#  'consolid ations.</w>': 41,
#  'osse ous</w>': 367,
#  'find ings.</w>': 112,
#  'mil d ly</w>': 116,
#  't o</w>': 305,
#  'moder ately</w>': 15,
#  'enlarged</w>': 48,
#  'distal</w>': 26,
#  'tip </w>': 89,
#  'd u al</w>': 13,
#  'lum en</w>': 5,
#  'cathe ter</w>': 47,
#  'ne ar</w>': 25,
#  'cav al</w>': 6,
#  'atrial</w>': 14,
#  'junc tion.</w>': 27,
#  'mil d</w>': 416,
#  'vascular</w>': 109,
#  'c eph alization</w>': 1,
#  'definit e</w>': 102,
#  'interstiti al</w>': 120,
#  'edem a</w>': 59,
#  'al ve olar</w>': 74,
#  'consolid ation.</w>': 349,
#  'demonstr ated.</w>': 23,
#  'contour s.</w>': 113,
#  'inter val</w>': 71,
#  'remo val</w>': 12,
#  'si ded</w>': 72,
#  'intra venous</w>': 1,
#  'cathe ter.</w>': 7,
#  'opac ities</w>': 201,
#  'obscur ing</w>': 2,
#  'hemidiaphragm s</w>': 7,
#  'sligh tly</w>': 24,
#  'impro ved</w>': 11,
#  'pri or</w>': 175,
#  'examin ation.</w>': 50,
#  'rib</w>': 127,
#  'fracture s</w>': 45,
#  'ag ain</w>': 83,
#  'not ed.</w>': 183,
#  'appearanc e.</w>': 99,
#  'are as</w>': 100,
#  'spin e</w>': 143,
#  'appear s</w>': 94,
#  'intac t.</w>': 314,
#  'displaced</w>': 59,
#  'fracture s.</w>': 41,
#  'two images.</w>': 19,
#  'engorg ement</w>': 16,
#  'app ear</w>': 378,
#  'identifi ed.</w>': 190,
#  'conv inc ing</w>': 14,
#  'contour s</w>': 370,
#  'low</w>': 152,
#  'volum es</w>': 121,
#  'opac ity</w>': 282,
#  'multi level</w>': 32,
#  'tortuosi ty</w>': 50,
#  'aort a.</w>': 154,
#  'vascular ity</w>': 313,
#  'structure s</w>': 519,
#  'pati ent</w>': 84,
#  'age.</w>': 36,
#  'lob ulated</w>': 3,
#  'par at racheal</w>': 15,
#  'strip e</w>': 3,
#  'possi b ly</w>': 20,
#  'struc ture</w>': 2,
#  'lymph </w>': 80,
#  '.</w>': 288,
#  'otherwi se</w>': 127,
#  'at</w>': 105,
#  'sc at ter ed</w>': 66,
#  'granulom as.</w>': 43,
#  'larg e</w>': 390,
#  'appreci able</w>': 1,
#  'unfolded</w>': 4,
#  'desc ending</w>': 19,
#  'aor tic</w>': 123,
#  'curvature</w>': 15,
#  'exagger ated</w>': 12,
#  'kyph osis.</w>': 13,
#  'diffu sely</w>': 5,
#  'osteop en ic.</w>': 2,
#  'minimal</w>': 98,
#  'anteri or</w>': 73,
#  'lo ss</w>': 20,
#  'sever al</w>': 14,
#  'vertebral</w>': 50,
#  'bodi es.</w>': 9,
#  'sk ele tal</w>': 75,
#  's o ft</w>': 125,
#  'tissu es</w>': 76,
#  'limit s.</w>': 964,
#  'w all</w>': 21,
#  'medi por t</w>': 3,
#  'placement</w>': 8,
#  'venous</w>': 27,
#  'superi or</w>': 30,
#  'effusion s.</w>': 148,
#  'frac ture</w>': 54,
#  'se en</w>': 132,
#  'vertebra e</w>': 31,
#  't 5</w>': 1,
#  'lum bar</w>': 33,
#  'l 2</w>': 2,
#  'scler osis</w>': 4,
#  'throughou t</w>': 29,
#  'righ tward</w>': 6,
#  'devi ation</w>': 3,
#  'trache a</w>': 71,
#  'unchang ed</w>': 97,
#  'comparis on</w>': 14,
#  'secon d ary</w>': 25,
#  'go i ter.</w>': 1,
#  'ad v anced</w>': 3,
#  'chang e</w>': 48,
#  'redemon stra tion</w>': 17,
#  'cop d</w>': 2,
#  'unchang ed.</w>': 68,
#  'atheroscler otic</w>': 91,
#  'calcific ations</w>': 59,
#  'se en.</w>': 278,
#  'non calcified</w>': 10,
#  'nodul e.</w>': 20,
#  'mediastin um.</w>': 24,
#  'visualiz ed</w>': 299,
#  'plat eli ke</w>': 5,
#  'h ori zon tal</w>': 3,
#  'bo th</w>': 134,
#  'ba ses</w>': 24,
#  'throu gh</w>': 14,
#  'th is</w>': 82,
#  'scar ring</w>': 79,
#  'sub segmental</w>': 45,
#  'atelectasi s.</w>': 105,
#  't</w>': 26,
#  'osteophy tes.</w>': 25,
#  'lobar</w>': 9,
#  'pneumoni a.</w>': 75,
#  'hilar</w>': 125,
#  'granulom a.</w>': 45,
#  'curv il in ear</w>': 7,
#  'density</w>': 69,
#  'al ong</w>': 25,
#  'cost ophrenic</w>': 94,
#  'sulc us</w>': 11,
#  'wh ic h</w>': 102,
#  'most </w>': 30,
#  'repres ents</w>': 27,
#  'sk inf old.</w>': 1,
#  'callu s</w>': 3,
#  '9 th</w>': 11,
#  'rib .</w>': 20,
#  'blunt ing</w>': 60,
#  'increas ed</w>': 80,
#  'opac ities.</w>': 86,
#  'an</w>': 80,
#  'aer ation</w>': 10,
#  'sub ph renic</w>': 2,
#  'intra perit on eal</w>': 39,
#  'ex tr al um inal</w>': 1,
#  'f re e</w>': 174,
#  'mid line.</w>': 62,
#  'compar ed</w>': 43,
#  'tub ular</w>': 2,
#  'densiti es</w>': 24,
#  'overl ying</w>': 88,
#  'coron ary</w>': 11,
#  'ar ter y</w>': 11,
#  'st ent s.</w>': 2,
#  'sm all</w>': 148,
#  'round</w>': 11,
#  'calcif ic</w>': 11,
#  'bilater al</w>': 157,
#  'lob es</w>': 5,
#  'examin ation</w>': 93,
#  'repres ent</w>': 65,
#  'sequela e</w>': 12,
#  'ol d</w>': 50,
#  'granulomat ous</w>': 105,
#  'infiltr ate</w>': 95,
#  're v eal</w>': 31,
#  'abnormaliti es.</w>': 97,
#  'vi e w</w>': 57,
#  're ve al s</w>': 19,
#  'effusion s</w>': 196,
#  'pneumo thorac es.</w>': 132,
#  'gener at or</w>': 12,
#  'two distal</w>': 1,
#  'le ads</w>': 41,
#  'atri um</w>': 23,
#  'ventric le.</w>': 20,
#  'spondy lo sis.</w>': 50,
#  '4</w>': 2,
#  'm m</w>': 36,
#  'mid lung</w>': 37,
#  't yp ical</w>': 57,
#  'find ing s</w>': 78,
#  'edem a.</w>': 117,
#  'susp ici ous</w>': 88,
#  'cardiom egal y</w>': 48,
#  'cali b er</w>': 2,
#  'vasculat ure.</w>': 21,
#  'g ros sly</w>': 180,
#  'intac t</w>': 31,
#  'ster not omy</w>': 81,
#  'clip s.</w>': 12,
#  'pat ch y</w>': 66,
#  'bi b asi lar</w>': 63,
#  'atelectasi s</w>': 106,
#  'ev ol ving</w>': 1,
#  'spac es</w>': 83,
#  'thorax</w>': 127,
#  'consist s</w>': 41,
#  'radiograph s</w>': 42,
#  'ch est .</w>': 72,
#  'posteri or</w>': 74,
#  'exclu ded</w>': 3,
#  'on</w>': 187,
#  'view .</w>': 46,
#  'abdom en</w>': 36,
#  'space</w>': 151,
#  'sub diaphragm atic</w>': 8,
#  'air .</w>': 11,
#  'inclu ded</w>': 1,
#  '1 0</w>': 6,
#  'nodul e</w>': 52,
#  'apex </w>': 20,
#  'project ing</w>': 34,
#  'be tw e en</w>': 6,
#  'th ir d</w>': 5,
#  'f our th</w>': 4,
#  'rib s.</w>': 14,
#  'g un sho t</w>': 1,
#  'w oun d.</w>': 1,
#  'chron ic</w>': 83,
#  'heal ed</w>': 16,
#  '1 0 th</w>': 4,
#  'poster ol ateral</w>': 4,
#  'fracture .</w>': 35,
#  'osse us</w>': 8,
#  'cer vic al</w>': 27,
#  'arthriti s.</w>': 2,
#  'bronch o vascular</w>': 58,
#  'crow ding</w>': 26,
#  'cav o atrial</w>': 12,
#  'promin ent</w>': 67,
#  'peri bronchi al</w>': 2,
#  'cu ff ing.</w>': 1,
#  'sub pleural</w>': 3,
#  'ou t lin ing</w>': 1,
#  'fi ssu re .</w>': 11,
#  'trache ost omy</w>': 6,
#  'tub e</w>': 19,
#  '5</w>': 8,
#  'c m</w>': 47,
#  'ab o ve</w>': 6,
#  'carin a.</w>': 3,
#  'diffu se</w>': 37,
#  'radiograph s.</w>': 2,
#  'nodul es.</w>': 7,
#  'granulom as</w>': 37,
#  'symmetr ic</w>': 6,
#  'ap ical</w>': 30,
#  'scar ring.</w>': 65,
#  'diaphragm s</w>': 11,
#  'flatten ed</w>': 18,
#  's om ew h at</w>': 14,
#  'shap ed.</w>': 1,
#  'cardi o th ym ic</w>': 1,
#  'ect atic</w>': 12,
#  'tortu ou s.</w>': 42,
#  'b asi lar</w>': 73,
#  're tic ular</w>': 4,
#  'hi at al</w>': 37,
#  'h er ni a.</w>': 30,
#  'bas e</w>': 79,
#  'ref lec t</w>': 9,
#  'ep icardial</w>': 10,
#  'f at</w>': 10,
#  'b re ast </w>': 14,
#  'tissu e.</w>': 1,
#  'widen ing.</w>': 24,
#  'appear ing</w>': 28,
#  'deform ity</w>': 41,
#  '7 th</w>': 10,
#  'sugg es tive</w>': 16,
#  'inj ur y.</w>': 8,
#  'expan ded.</w>': 104,
#  'infiltr ate.</w>': 96,
#  'pneumoni a</w>': 40,
#  'adenop ath y</w>': 48,
#  'nodul es</w>': 119,
#  'mas ses.</w>': 81,
#  'sign ific ant</w>': 37,
#  'con g es tion.</w>': 16,
#  'th e y</w>': 3,
#  'r e</w>': 2,
#  'o v oid</w>': 3,
#  '3 5</w>': 3,
#  'retro cardiac</w>': 23,
#  'are a</w>': 31,
#  'ap </w>': 25,
#  'no t</w>': 92,
#  'wel l</w>': 64,
#  'd edic ated</w>': 2,
#  'sc an</w>': 7,
#  're com m end ed.</w>': 2,
#  'lymph adenop at hy.</w>': 4,
#  'destruc tive</w>': 8,
#  'le sion s.</w>': 3,
#  'pres ent</w>': 133,
#  'mul tip le</w>': 51,
#  'rib s</w>': 14,
#  'previ ous</w>': 61,
#  'scoliosis</w>': 24,
#  'consolid ations</w>': 14,
#  'sugg est</w>': 85,
#  'h as</w>': 79,
#  'be en</w>': 54,
#  'resol u tion</w>': 5,
#  'crow d ing.</w>': 31,
#  'disc re te</w>': 8,
#  'hemidiaphragm </w>': 43,
#  'p ic c</w>': 21,
#  'mid </w>': 54,
#  's v c</w>': 5,
#  'fe ed ing</w>': 4,
#  'c our ses</w>': 3,
#  'be low</w>': 8,
#  'diaphragm .</w>': 51,
#  'sign ific ant ly</w>': 23,
#  'enlarg ed.</w>': 113,
#  'arthri tic</w>': 29,
#  'fe w</w>': 10,
#  'specific ally</w>': 80,
#  'cardi o</w>': 69,
#  'st om ac h</w>': 7,
#  'elev ation.</w>': 3,
#  'repres ent ing</w>': 20,
#  'stu dy</w>': 22,
#  'limit ed</w>': 37,
#  'b y</w>': 23,
#  'bo dy</w>': 37,
#  'h ab it us.</w>': 7,
#  'promin ence</w>': 34,
#  'co ar sen ed</w>': 4,
#  'mark ing s</w>': 49,
#  'develop ing</w>': 4,
#  'abnormal ity</w>': 32,
#  'ple ura </w>': 5,
#  'demonstr ates</w>': 8,
#  'disc </w>': 27,
#  'thorac ol um bar</w>': 36,
#  'as</w>': 44,
#  'cardiom egal y.</w>': 81,
#  'ne g ative</w>': 109,
#  'tech ni qu e.</w>': 8,
#  'vi si ble</w>': 138,
#  'hypo inflated</w>': 22,
#  'b u t</w>': 47,
#  'd ue</w>': 29,
#  'volum e</w>': 16,
#  'over lo ad .</w>': 1,
#  'residu al</w>': 12,
#  't un n el ed</w>': 4,
#  'di al y sis</w>': 4,
#  'osteop eni a</w>': 9,
#  'e k g</w>': 1,
#  'le ad s.</w>': 4,
#  'm a y</w>': 90,
#  'b e</w>': 81,
#  'par ti ally</w>': 17,
#  's</w>': 22,
#  'k no w n </w>': 8,
#  'th y ro id</w>': 1,
#  'mas s.</w>': 3,
#  'opac ific ation.</w>': 6,
#  'scoli otic</w>': 4,
#  'g i ven </w>': 11,
#  'overl app ing</w>': 5,
#  'tissu e</w>': 45,
#  'silhouet tes.</w>': 5,
#  'hyperexpan sion</w>': 16,
#  'loc ul ated.</w>': 2,
#  'scler otic</w>': 6,
#  'le sion</w>': 9,
#  'prox imal</w>': 11,
#  'clavic le.</w>': 7,
#  'h a ve</w>': 75,
#  'inter v al.</w>': 66,
#  'mid d le</w>': 33,
#  'lob e.</w>': 91,
#  'inferi or</w>': 11,
#  'exclu ded.</w>': 8,
#  'bac k g round</w>': 4,
#  'mark ed</w>': 14,
#  'centr il ob ular</w>': 1,
#  'st re ak y</w>': 55,
#  'appearanc e</w>': 59,
#  'cardi a</w>': 4,
#  'k ne e</w>': 5,
#  'sever e</w>': 23,
#  'tr ic om par tm ental</w>': 1,
#  'obli ter ation</w>': 2,
#  'jo in t</w>': 15,
#  'spac es.</w>': 1,
#  'disloc ation.</w>': 7,
#  'medi al</w>': 23,
#  'compar tm ent.</w>': 1,
#  'evalu ation</w>': 23,
#  'pat el lo fem or al</w>': 1,
#  'spac e.</w>': 4,
#  't op </w>': 18,
#  'calcific ation.</w>': 18,
#  'n on</w>': 3,
#  'ev ent ra tion</w>': 22,
#  'identifi ed</w>': 42,
#  'previ ou sly</w>': 17,
#  'larg ely</w>': 2,
#  's inc e</w>': 21,
#  'comp u ted</w>': 1,
#  't om o gra m.</w>': 1,
#  'hyper inflation</w>': 18,
#  'comparis on.</w>': 6,
#  'icd</w>': 11,
#  'p acemak er .</w>': 3,
#  'over all</w>': 16,
#  'apex .</w>': 13,
#  'demonstr ated</w>': 20,
#  'l or d otic</w>': 6,
#  'con si der ing</w>': 5,
#  'di ff er enc es</w>': 4,
#  'tech n ical</w>': 8,
#  'fac tor s</w>': 8,
#  'dense</w>': 20,
#  'suggest s</w>': 9,
#  'proc ess.</w>': 20,
#  'w as</w>': 36,
#  'ob tain ed</w>': 5,
#  'con di tion.</w>': 1,
#  'gre at er</w>': 31,
#  'le f t.</w>': 24,
#  'regi on.</w>': 13,
#  'cardi o thoracic</w>': 1,
#  'ra ti o</w>': 1,
#  '1 6</w>': 4,
#  'two 2 4</w>': 1,
#  'co ar se</w>': 7,
#  'peri hilar</w>': 30,
#  'p red omin anc e.</w>': 1,
#  'th an</w>': 41,
#  'larg er</w>': 3,
#  'calcific ation</w>': 36,
#  'in vol ving</w>': 12,
#  'abdom inal</w>': 10,
#  'p a</w>': 36,
#  'superim pos ed</w>': 15,
#  'structure s.</w>': 7,
#  'fi r st</w>': 9,
#  'co s tic arti la ge</w>': 2,
#  'junc tion</w>': 5,
#  'cont ribu tes</w>': 1,
#  'e lec tr on ic</w>': 3,
#  'de vic e</w>': 13,
#  'hear t.</w>': 31,
#  'chang es.</w>': 33,
#  'view s.</w>': 3,
#  'a f ter</w>': 1,
#  'cir r h otic</w>': 1,
#  'retro stern al</w>': 12,
#  'f av or ed</w>': 3,
#  'osteophy tes</w>': 14,
#  'a spec t</w>': 11,
#  'st able.</w>': 106,
#  'pro b able</w>': 16,
#  'opac ity.</w>': 75,
#  'fore i gn </w>': 12,
#  'in d ic ate</w>': 8,
#  'widen ing</w>': 11,
#  'ch ar ac teri stic</w>': 4,
#  'inj ur y</w>': 6,
#  'hyper lucenc y</w>': 4,
#  'flatten ing</w>': 29,
#  'emphysem at ous</w>': 25,
#  'post op er ative</w>': 12,
#  'thorac o t omy</w>': 3,
#  'lob ectomy.</w>': 3,
#  'mas s</w>': 21,
#  'cali b er .</w>': 10,
#  'radiograph .</w>': 6,
#  'st ent</w>': 5,
#  'gra ft</w>': 4,
#  'overli es</w>': 10,
#  'remain s</w>': 30,
#  'elev ated.</w>': 11,
#  'in distinc t</w>': 6,
#  'margin ation.</w>': 5,
#  'acc oun t ing</w>': 2,
#  'low .</w>': 27,
#  'w er e</w>': 31,
#  'ob tain ed.</w>': 43,
#  'configura tion.</w>': 25,
#  'aer ated.</w>': 25,
#  'enlarg em ent.</w>': 9,
#  's om e</w>': 34,
#  'relat es</w>': 1,
#  '1 9</w>': 4,
#  'inter rup tion</w>': 1,
#  'level</w>': 12,
#  'overl ap </w>': 5,
#  'clavic le</w>': 23,
#  'a z y go s</w>': 7,
#  've in.</w>': 8,
#  'densiti es.</w>': 2,
#  'st at us</w>': 17,
#  'po st</w>': 22,
#  'c ab g .</w>': 20,
#  'st ent.</w>': 7,
#  'vascular ity.</w>': 38,
#  'epig ast ri um</w>': 1,
#  'abdom en.</w>': 17,
#  'suggest ing</w>': 21,
#  'two </w>': 12,
#  'tub es</w>': 2,
#  'pri or.</w>': 15,
#  'improv ement</w>': 8,
#  'flu id.</w>': 34,
#  'end o trache al</w>': 3,
#  'ap prox im ately</w>': 22,
#  '4 5</w>': 2,
#  'inter n al</w>': 8,
#  'j u g ular</w>': 8,
#  'ap prox im ating</w>': 3,
#  'hi gh</w>': 4,
#  's v c .</w>': 31,
#  'sequela </w>': 18,
#  'consolid ating</w>': 5,
#  'engorg ed.</w>': 8,
#  'infiltr at es.</w>': 67,
#  'mid lung .</w>': 21,
#  'b order line</w>': 30,
#  'tortu ro us</w>': 2,
#  'be t ter</w>': 6,
#  'shoul der</w>': 9,
#  'd ated</w>': 3,
#  'lucenc y</w>': 19,
#  'b eni gn .</w>': 1,
#  'jo int s.</w>': 3,
#  'rot ated</w>': 9,
#  'ques tion</w>': 6,
#  'enlarg ement</w>': 20,
#  'appreci ated</w>': 5,
#  'lob es.</w>': 15,
#  'chang e.</w>': 13,
#  'si mil ar</w>': 25,
#  'exam s.</w>': 3,
#  'f u sion</w>': 13,
#  'di sh </w>': 4,
#  'calcific ations.</w>': 21,
#  'nod ular</w>': 50,
#  'over </w>': 66,
#  'f if th</w>': 3,
#  'si x</w>': 1,
#  'thick en ing.</w>': 13,
#  'humer al</w>': 16,
#  'prosthe sis</w>': 3,
#  'in comple te ly</w>': 8,
#  'evalu ated.</w>': 4,
#  'evalu ated</w>': 5,
#  'bilater ally</w>': 42,
#  'rot ated.</w>': 6,
#  'elev ated</w>': 14,
#  'comp ati ble</w>': 46,
#  'accentu ated.</w>': 2,
#  'disloc ation</w>': 4,
#  'humer us.</w>': 6,
#  'cor relat e</w>': 8,
#  'clin ic ally.</w>': 3,
#  'j u x t a hilar</w>': 1,
#  'moder ate</w>': 59,
#  'e ti olog y</w>': 3,
#  'determin ed.</w>': 1,
#  'c t</w>': 14,
#  'b eni gn </w>': 1,
#  'e ti olog y.</w>': 1,
#  'alignm ent.</w>': 3,
#  'pro b ably</w>': 9,
#  'most ly</w>': 1,
#  'di ff ic ul t</w>': 1,
#  'comple te ly</w>': 1,
#  'exclu de</w>': 3,
#  'ex ten sive</w>': 10,
#  'sup ra hilar</w>': 6,
#  'wh o se</w>': 3,
#  'appearanc es</w>': 1,
#  'met ast atic</w>': 3,
#  'x</w>': 12,
#  '2 1</w>': 2,
#  '6 th</w>': 12,
#  '1 2</w>': 5,
#  'inter space</w>': 2,
#  '5 th</w>': 10,
#  'righ t.</w>': 13,
#  '1 1</w>': 2,
#  'inter spac es</w>': 1,
#  'if </w>': 4,
#  'al re ad y</w>': 2,
#  'perform ed</w>': 5,
#  'cont ra st</w>': 11,
#  'en h anced</w>': 1,
#  'w o ul d</w>': 6,
#  'su it ed</w>': 1,
#  'evalu ate</w>': 3,
#  'th es e</w>': 19,
#  'axil lar y</w>': 9,
#  'atri um.</w>': 13,
#  'rec ess</w>': 4,
#  'con flu ent</w>': 7,
#  'posteri orly.</w>': 2,
#  'bi ap ical</w>': 25,
#  'stu d y.</w>': 29,
#  'ect a tic.</w>': 6,
#  'parenchym al</w>': 15,
#  'ba se.</w>': 57,
#  'blunt ed.</w>': 6,
#  'heal ed.</w>': 1,
#  'h er ni a</w>': 15,
#  'ster not om y.</w>': 13,
#  'blunt ing.</w>': 3,
#  'under g one</w>': 1,
#  'mark ings.</w>': 13,
#  'bul l ous</w>': 4,
#  'f oun d</w>': 1,
#  'thorax.</w>': 6,
#  'ful l n ess</w>': 4,
#  'hil um</w>': 10,
#  'pro g res sion</w>': 1,
#  'retro hilar</w>': 1,
#  'sc an .</w>': 4,
#  'f oun d.</w>': 1,
#  'v ag ue</w>': 15,
#  'relat ed</w>': 14,
#  'sc ap ular</w>': 1,
#  'hyper inflated</w>': 32,
#  'di a me ter</w>': 8,
#  'le sion.</w>': 2,
#  'develop ed</w>': 9,
#  'deform ities</w>': 19,
#  'comp on ent</w>': 1,
#  'cor re spond s</w>': 2,
#  'one</w>': 14,
#  'project ed</w>': 8,
#  'position ing</w>': 3,
#  'p acemak er</w>': 18,
#  'it s</w>': 7,
#  'thre ele ads</w>': 1,
#  'addi tion al</w>': 4,
#  'p ac ing</w>': 4,
#  'al s o</w>': 41,
#  'min im ally</w>': 4,
#  'ba ses.</w>': 17,
#  'dextro </w>': 5,
#  'position al.</w>': 3,
#  'stu di es.</w>': 3,
#  't 9</w>': 6,
#  'wor se</w>': 4,
#  'blun ted</w>': 7,
#  'sub cla vi an</w>': 14,
#  'posteri orly</w>': 4,
#  'post surgical</w>': 29,
#  'f u sion.</w>': 6,
#  't 4</w>': 1,
#  't 7</w>': 2,
#  'tortuosi ty.</w>': 12,
#  'ex tern al</w>': 14,
#  'mon it or</w>': 12,
#  'airway s.</w>': 5,
#  'inc id ental</w>': 4,
#  'no te</w>': 10,
#  'diaphragm </w>': 18,
#  'air spac e.</w>': 6,
#  'irreg ular</w>': 10,
#  'persist ent</w>': 21,
#  'dextro scoliosis</w>': 13,
#  'imag ing.</w>': 2,
#  'he a d</w>': 7,
#  'anch or s.</w>': 1,
#  'kyph osis</w>': 9,
#  'di m en sion</w>': 2,
#  '3 r d</w>': 2,
#  '4 th</w>': 4,
#  'be y on d</w>': 1,
#  'sk in</w>': 3,
#  'fol d</w>': 1,
#  'artifac t.</w>': 7,
#  'ectasi a</w>': 19,
#  'irreg ular ity</w>': 9,
#  'in determin ate</w>': 8,
#  'deform ities.</w>': 6,
#  'st ents</w>': 2,
#  'visualiz ed.</w>': 9,
#  'gre at est</w>': 5,
#  'inclu ding</w>': 5,
#  'projec tion.</w>': 13,
#  'ear ly</w>': 6,
#  'i v c</w>': 3,
#  'proc ed ure.</w>': 5,
#  'arteri es.</w>': 6,
#  'as s oc i ated</w>': 16,
#  'posi tion.</w>': 17,
#  'ar is ing</w>': 1,
#  'opac ific ation</w>': 9,
#  'levo curvature</w>': 4,
#  'shap ed</w>': 5,
#  'scoliosis.</w>': 5,
#  'levo scoliosis</w>': 9,
#  'perit racheal</w>': 1,
#  'hypo inflat ed.</w>': 12,
#  'decreas ed</w>': 11,
#  'peripher al</w>': 11,
#  'abnorm al</w>': 10,
#  'demonstr ate</w>': 30,
#  'inf ra hilar</w>': 6,
#  '9</w>': 3,
#  'sh i el ded.</w>': 2,
#  'decreas ed.</w>': 3,
#  'disc oid</w>': 3,
#  'vasculat ur ity</w>': 1,
#  'increas ed.</w>': 3,
#  'under l ying</w>': 8,
#  'com pres sive</w>': 2,
#  'siz ed</w>': 11,
#  'osteophy te</w>': 9,
#  'form ation</w>': 8,
#  'h ow e ver </w>': 15,
#  'degener ation</w>': 2,
#  'zon e</w>': 9,
#  'line</w>': 22,
#  'granulomat a</w>': 3,
#  'bodi es</w>': 13,
#  'overl ap .</w>': 1,
#  'm ain tain ed.</w>': 5,
#  'fi ven on rib</w>': 1,
#  'b ear ing</w>': 1,
#  't yp e</w>': 1,
#  'alignm ent</w>': 4,
#  'am oun t</w>': 14,
#  'sto ol .</w>': 1,
#  'unremark able</w>': 40,
#  'atheroscler osis</w>': 8,
#  'wor sen ed</w>': 1,
#  'possi ble</w>': 7,
#  'f at .</w>': 6,
#  'an y</w>': 30,
#  'un der</w>': 44,
#  'g ast ro st omy</w>': 2,
#  'disloc ations.</w>': 3,
#  'convex ity</w>': 5,
#  't ri ang ular</w>': 1,
#  'mea sur ing</w>': 16,
#  '5 8</w>': 1,
#  '6 0</w>': 1,
#  'di a me ter.</w>': 12,
#  'ob s er ved</w>': 1,
#  'thick en ing</w>': 26,
#  'parenchym a</w>': 3,
#  'n g</w>': 2,
#  'remo v ed.</w>': 8,
#  'ob vi ous</w>': 4,
#  'non displaced</w>': 2,
#  'su ture</w>': 5,
#  'm ater i al</w>': 4,
#  'surg er y.</w>': 7,
#  'sub stern al</w>': 1,
#  're la ti vely</w>': 4,
#  'con g es tion</w>': 11,
#  'ext rem ity</w>': 7,
#  'termin ates</w>': 2,
#  'implant able</w>': 3,
#  'cop d.</w>': 4,
#  'd ating</w>': 2,
#  'bac k</w>': 2,
#  'sh ad ow s</w>': 4,
#  'pierc ings.</w>': 1,
#  'project s</w>': 10,
#  'projec tion</w>': 10,
#  'sub op tim al</w>': 1,
#  'co ul d</w>': 21,
#  'ra i se</w>': 1,
#  'larg e.</w>': 10,
#  'c lo sure</w>': 3,
#  'lung .</w>': 28,
#  'a icd</w>': 4,
#  'placem ent.</w>': 4,
#  'one in</w>': 1,
#  'an o ther</w>': 4,
#  'ventric le</w>': 9,
#  'strip e.</w>': 1,
#  'ac tive</w>': 11,
#  'non spec if ic</w>': 1,
#  're la tive</w>': 8,
#  'lucenc i es</w>': 3,
#  'emphysem a</w>': 4,
#  'se p tal</w>': 3,
#  'oc c lu der</w>': 2,
#  'curvat ure.</w>': 2,
#  'consolid ative</w>': 5,
#  'radiograph ic</w>': 4,
#  'm it ral</w>': 5,
#  'val ve</w>': 12,
#  'cont inu ed</w>': 2,
#  'e spec i ally</w>': 1,
#  'accentu ated</w>': 7,
#  'inter rup ted</w>': 1,
#  'c an no t</w>': 9,
#  'mark ing.</w>': 1,
#  'asp ect .</w>': 1,
#  'de fi br il lat or</w>': 7,
#  'nod e</w>': 3,
#  'as be sto s</w>': 1,
#  'ex po su re .</w>': 2,
#  'bul la e</w>': 5,
#  'inter lobar</w>': 1,
#  'fi s sur al</w>': 3,
#  'rec es ses</w>': 1,
#  'scar .</w>': 6,
#  'mid thoracic</w>': 20,
#  'g ro ss</w>': 6,
#  'collec tion</w>': 6,
#  're placem ent.</w>': 6,
#  'k ne e.</w>': 2,
#  't o tal</w>': 2,
#  'compar tm ent</w>': 2,
#  'mark ed ly</w>': 3,
#  'narrow .</w>': 1,
#  'fem ur </w>': 5,
#  'ti bi al</w>': 1,
#  'plat e a us.</w>': 1,
#  'cavit ary</w>': 11,
#  'm ast ectomy.</w>': 4,
#  'fibro sis.</w>': 6,
#  'regi on</w>': 21,
#  '2</w>': 3,
#  'ver su s</w>': 29,
#  'thre e</w>': 3,
#  'larg est</w>': 2,
#  'mea su re s</w>': 10,
#  'hil um.</w>': 8,
#  'i t</w>': 10,
#  'o ther</w>': 8,
#  'sti m ulat or</w>': 5,
#  'mid line</w>': 14,
#  'trache a.</w>': 4,
#  'clavic le s</w>': 1,
#  'evalu ation.</w>': 6,
#  'unfol ding</w>': 8,
#  'su ture s</w>': 5,
#  'b yp as s</w>': 6,
#  'crow ded</w>': 2,
#  'over t</w>': 8,
#  'artifac t</w>': 6,
#  'relat ing</w>': 1,
#  'ven a</w>': 1,
#  'defin i tive</w>': 1,
#  'tra n s met at ar s al</w>': 1,
#  'am p u t ation.</w>': 2,
#  'er osi on s</w>': 1,
#  'infec tions.</w>': 1,
#  'ap ic es</w>': 6,
#  'obsc ure</w>': 5,
#  'end .</w>': 1,
#  's ing le</w>': 6,
#  'cardi op ul monary</w>': 7,
#  'foc us</w>': 2,
#  'thin</w>': 4,
#  'ling ular</w>': 6,
#  'sc ar</w>': 15,
#  'mas sli ke</w>': 3,
#  'c a u d al</w>': 1,
#  'frac t ur ed.</w>': 2,
#  'rec tal</w>': 1,
#  'b al lo on</w>': 1,
#  'bo ch d al e k</w>': 2,
#  'two icd</w>': 1,
#  'exp ect ed</w>': 11,
#  'prosthe ses</w>': 2,
#  'mediastin um .there</w>': 1,
#  'w ed ge</w>': 10,
#  't1 2 .</w>': 4,
#  'rec ur r ence</w>': 1,
#  'str ing y</w>': 1,
#  'post tra um atic</w>': 5,
#  'ver ter bro plasty</w>': 2,
#  ...}

# %%
sorted_tokens_tuple
# Out:
# [('pneumothorax</w>', 1128),
#  ('hemidiaphragm', 107),
#  ('mediastinal</w>', 760),
#  ('atheroscler', 111),
#  ('abnormaliti', 107),
#  ('clavicular</w>', 13),
#  ('scoliosis.</w>', 8),
#  ('calcified</w>', 358),
#  ('atelectasi', 211),
#  ('interstiti', 125),
#  ('granulomat', 109),
#  ('hyperexpan', 98),
#  ('displaced</w>', 61),
#  ('radiograph', 61),
#  ('vertebral</w>', 52),
#  ('segmental</w>', 46),
#  ('scoliosis</w>', 46),
#  ('curvature</w>', 24),
#  ('inflation</w>', 22),
#  ('placement</w>', 9),
#  ('alization</w>', 4),
#  ('thoracic</w>', 544),
#  ('mediastin', 537),
#  ('structure', 527),
#  ('vascular</w>', 167),
#  ('appearanc', 159),
#  ('inflated</w>', 125),
#  ('surgical</w>', 106),
#  ('diaphragm', 101),
#  ('ophrenic</w>', 98),
#  ('enlarged</w>', 49),
#  ('configura', 44),
#  ('throughou', 30),
#  ('parenchym', 21),
#  ('icardial</w>', 18),
#  ('cholecyst', 16),
#  ('position</w>', 16),
#  ('chondral</w>', 8),
#  ('unfolded</w>', 5),
#  ('hypoventi', 4),
#  ('artifactu', 3),
#  ('pleural</w>', 2249),
#  ('thorax.</w>', 1070),
#  ('consolid', 1016),
#  ('silhouet', 954),
#  ('unremark', 528),
#  ('cardiac</w>', 415),
#  ('vascular', 351),
#  ('effusion', 345),
#  ('abnormal', 320),
#  ('visualiz', 308),
#  ('vasculat', 273),
#  ('granulom', 235),
#  ('identifi', 232),
#  ('calcific', 134),
#  ('fracture', 121),
#  ('pneumoni', 115),
#  ('minimal</w>', 99),
#  ('specific', 82),
#  ('demonstr', 81),
#  ('ations.</w>', 71),
#  ('density</w>', 70),
#  ('emphysem', 65),
#  ('tortuosi', 62),
#  ('osteophy', 49),
#  ('vertebra', 37),
#  ('images.</w>', 23),
#  ('comparis', 20),
#  ('ectomy.</w>', 16),
#  ('racheal</w>', 16),
#  ('determin', 15),
#  ('peripher', 13),
#  ('tubercul', 11),
#  ('position', 9),
#  ('question', 8),
#  ('arthriti', 6),
#  ('distribu', 4),
#  ('chondrom', 3),
#  ('radiogra', 1),
#  ('monary</w>', 1093),
#  ('contour', 953),
#  ('cardiom', 860),
#  ('ation.</w>', 469),
#  ('stable</w>', 465),
#  ('degener', 431),
#  ('bilater', 388),
#  ('infiltr', 290),
#  ('unchang', 165),
#  ('thorax</w>', 131),
#  ('otherwi', 128),
#  ('consist', 124),
#  ('definit', 105),
#  ('increas', 93),
#  ('ities.</w>', 92),
#  ('posteri', 80),
#  ('ations</w>', 77),
#  ('project', 53),
#  ('flatten', 48),
#  ('ventric', 36),
#  ('sequela', 31),
#  ('suggest', 31),
#  ('venous</w>', 28),
#  ('ending</w>', 28),
#  ('endplat', 27),
#  ('distal</w>', 27),
#  ('redemon', 27),
#  ('quadran', 26),
#  ('atrial</w>', 26),
#  ('densiti', 26),
#  ('persist', 26),
#  ('develop', 21),
#  ('superim', 17),
#  ('decreas', 17),
#  ('obstruc', 16),
#  ('exagger', 15),
#  ('artifac', 15),
#  ('destruc', 14),
#  ('appreci', 13),
#  ('calcifi', 13),
#  ('prosthe', 12),
#  ('ectomy</w>', 11),
#  ('bronchi', 10),
#  ('accentu', 10),
#  ('symmetr', 8),
#  ('distinc', 8),
#  ('perform', 8),
#  ('astric</w>', 8),
#  ('ulated</w>', 7),
#  ('lowing</w>', 7),
#  ('ically</w>', 7),
#  ('esophag', 7),
#  ('ateral</w>', 6),
#  ('.there</w>', 6),
#  ('plasty</w>', 6),
#  ('atelect', 6),
#  ('tions.</w>', 5),
#  ('implant', 5),
#  ('cartila', 3),
#  ('lation</w>', 2),
#  ('pneumon', 2),
#  ('there</w>', 2176),
#  ('heart</w>', 1904),
#  ('focal</w>', 1567),
#  ('pneumo', 1191),
#  ('sion.</w>', 980),
#  ('space</w>', 894),
#  ('right</w>', 875),
#  ('ation</w>', 859),
#  ('ediast', 737),
#  ('clear</w>', 623),
#  ('acute</w>', 611),
#  ('able.</w>', 597),
#  ('ative</w>', 554),
#  ('lower</w>', 226),
#  ('ities</w>', 224),
#  ('ally.</w>', 190),
#  ('hilar</w>', 172),
#  ('thorac', 172),
#  ('examin', 148),
#  ('enlarg', 143),
#  ('tion.</w>', 133),
#  ('ings.</w>', 126),
#  ('appear', 122),
#  ('promin', 113),
#  ('repres', 112),
#  ('trache', 86),
#  ('ated.</w>', 84),
#  ('deform', 75),
#  ('remain', 74),
#  ('anteri', 74),
#  ('ring.</w>', 67),
#  ('line.</w>', 64),
#  ('bronch', 60),
#  ('adenop', 59),
#  ('spondy', 54),
#  ('compar', 46),
#  ('ement</w>', 44),
#  ('level</w>', 44),
#  ('ately</w>', 39),
#  ('superi', 31),
#  ('clavic', 31),
#  ('arthri', 29),
#  ('lucenc', 27),
#  ('osis.</w>', 26),
#  ('engorg', 25),
#  ('dense</w>', 25),
#  ('dextro', 25),
#  ('projec', 25),
#  ('ectasi', 24),
#  ('airway', 22),
#  ('acemak', 22),
#  ('overli', 20),
#  ('ating</w>', 20),
#  ('residu', 17),
#  ('inflat', 17),
#  ('osteop', 16),
#  ('round</w>', 15),
#  ('disloc', 15),
#  ('inferi', 13),
#  ('comple', 13),
#  ('collec', 12),
#  ('obscur', 11),
#  ('calcif', 11),
#  ('improv', 11),
#  ('abnorm', 11),
#  ('lobar</w>', 10),
#  ('arteri', 10),
#  ('placem', 10),
#  ('termin', 9),
#  ('alignm', 8),
#  ('tward</w>', 7),
#  ('margin', 7),
#  ('convex', 7),
#  ('tions</w>', 7),
#  ('narrow', 6),
#  ('retrac', 6),
#  ('poster', 5),
#  ('ental</w>', 5),
#  ('atory</w>', 5),
#  ('anced</w>', 4),
#  ('orly.</w>', 4),
#  ('itis.</w>', 4),
#  ('ymmetr', 4),
#  ('remark', 3),
#  ('renic</w>', 2),
#  ('curvat', 2),
#  ('lasty</w>', 1),
#  ('thin</w>', 1390),
#  ('limit', 1369),
#  ('sion</w>', 1113),
#  ('clear', 771),
#  ('inal</w>', 759),
#  ('left</w>', 752),
#  ('chang', 597),
#  ('lung</w>', 596),
#  ('ity.</w>', 413),
#  ('ence</w>', 363),
#  ('intac', 345),
#  ('later', 277),
#  ('volum', 228),
#  ('ally</w>', 224),
#  ('nodul', 198),
#  ('inter', 159),
#  ('ded.</w>', 150),
#  ('tion</w>', 143),
#  ('tissu', 129),
#  ('expan', 127),
#  ('ical</w>', 125),
#  ('ent.</w>', 119),
#  ('tortu', 113),
#  ('otic</w>', 113),
#  ('ated</w>', 111),
#  ('ate.</w>', 103),
#  ('ular</w>', 102),
#  ('centr', 100),
#  ('overl', 100),
#  ('ses.</w>', 100),
#  ('ying</w>', 97),
#  ('chron', 87),
#  ('cardi', 87),
#  ('lymph', 86),
#  ('ring</w>', 84),
#  ('ing.</w>', 83),
#  ('hyper', 83),
#  ('previ', 79),
#  ('able</w>', 78),
#  ('olar</w>', 75),
#  ('moder', 74),
#  ('blunt', 69),
#  ('abdom', 68),
#  ('line</w>', 66),
#  ('ture</w>', 61),
#  ('sis.</w>', 58),
#  ('tive</w>', 57),
#  ('cathe', 54),
#  ('ates</w>', 44),
#  ('ding</w>', 43),
#  ('diffu', 42),
#  ('evalu', 42),
#  ('intra', 41),
#  ('retro', 41),
#  ('thick', 41),
#  ('perit', 40),
#  ('sever', 39),
#  ('age.</w>', 37),
#  ('widen', 37),
#  ('ents</w>', 36),
#  ('atic</w>', 36),
#  ('multi', 33),
#  ('order', 32),
#  ('sligh', 31),
#  ('tes.</w>', 30),
#  ('humer', 30),
#  ('osis</w>', 29),
#  ('ure.</w>', 29),
#  ('possi', 28),
#  ('secon', 27),
#  ('relat', 24),
#  ('ess.</w>', 23),
#  ('irreg', 23),
#  ('ther</w>', 21),
#  ('infec', 21),
#  ('ter.</w>', 20),
#  ('shoul', 20),
#  ('stern', 19),
#  ('gener', 16),
#  ('throu', 14),
#  ('ving</w>', 14),
#  ('exclu', 14),
#  ('tic.</w>', 14),
#  ('scler', 13),
#  ('sive</w>', 13),
#  ('cavit', 13),
#  ('fibro', 13),
#  ('defin', 13),
#  ('pneum', 13),
#  ('coron', 12),
#  ('resol', 12),
#  ('imal</w>', 12),
#  ('ably</w>', 12),
#  ('unfol', 12),
#  ('impro', 11),
#  ('under', 11),
#  ('sure</w>', 11),
#  ('stic</w>', 10),
#  ('orly</w>', 8),
#  ('vely</w>', 8),
#  ('level', 8),
#  ('fragm', 8),
#  ('inclu', 7),
#  ('carin', 7),
#  ('osteo', 7),
#  ('ures</w>', 7),
#  ('sely</w>', 6),
#  ('spond', 5),
#  ('resul', 5),
#  ('three', 5),
#  ('densi', 5),
#  ('strip', 4),
#  ('callu', 4),
#  ('scoli', 4),
#  ('enic</w>', 4),
#  ('ticul', 4),
#  ('foot</w>', 4),
#  ('pierc', 3),
#  ('displ', 3),
#  ('airwa', 3),
#  ('verte', 3),
#  ('radio', 3),
#  ('super', 3),
#  ('aced</w>', 3),
#  ('struc', 2),
#  ('old.</w>', 2),
#  ('bral</w>', 2),
#  ('resid', 2),
#  ('pleur', 1),
#  ('align', 1),
#  ('demon', 1),
#  ('confi', 1),
#  ('the</w>', 5780),
#  ('norm', 3236),
#  ('and</w>', 2552),
#  ('effu', 2035),
#  ('lung', 1848),
#  ('al.</w>', 1151),
#  ('ous</w>', 748),
#  ('ed.</w>', 701),
#  ('ity</w>', 693),
#  ('opac', 659),
#  ('spin', 562),
#  ('dise', 552),
#  ('ent</w>', 536),
#  ('es.</w>', 486),
#  ('thou', 407),
#  ('larg', 407),
#  ('se.</w>', 386),
#  ('ear</w>', 385),
#  ('osse', 375),
#  ('ing</w>', 370),
#  ('evid', 326),
#  ('en.</w>', 300),
#  ('est</w>', 288),
#  ('aort', 261),
#  ('ure</w>', 254),
#  ('ase</w>', 227),
#  ('pres', 211),
#  ('ate</w>', 209),
#  ('air</w>', 205),
#  ('sly</w>', 198),
#  ('ble</w>', 192),
#  ('find', 190),
#  ('all</w>', 186),
#  ('tal</w>', 184),
#  ('edem', 176),
#  ('tic</w>', 163),
#  ('ded</w>', 160),
#  ('low</w>', 160),
#  ('scar', 152),
#  ('lar</w>', 137),
#  ('egal', 130),
#  ('rib</w>', 128),
#  ('view', 117),
#  ('te.</w>', 108),
#  ('sugg', 104),
#  ('cost', 98),
#  ('ted</w>', 97),
#  ('spac', 95),
#  ('over', 95),
#  ('ster', 94),
#  ('susp', 92),
#  ('omy</w>', 92),
#  ('mark', 87),
#  ('val</w>', 86),
#  ('pati', 86),
#  ('ain</w>', 84),
#  ('one</w>', 80),
#  ('clip', 79),
#  ('eal</w>', 77),
#  ('ific', 76),
#  ('tes</w>', 70),
#  ('bar</w>', 69),
#  ('elev', 65),
#  ('um.</w>', 64),
#  ('ter</w>', 63),
#  ('sign', 61),
#  ('der</w>', 61),
#  ('crow', 59),
#  ('tain', 59),
#  ('frac', 57),
#  ('ses</w>', 49),
#  ('ary</w>', 49),
#  ('comp', 49),
#  ('post', 49),
#  ('as.</w>', 45),
#  ('ads</w>', 45),
#  ('ant</w>', 39),
#  ('disc', 38),
#  ('hypo', 37),
#  ('regi', 37),
#  ('atri', 36),
#  ('prox', 36),
#  ('id.</w>', 36),
#  ('apex', 34),
#  ('remo', 33),
#  ('junc', 32),
#  ('le.</w>', 32),
#  ('peri', 32),
#  ('most', 31),
#  ('hear', 31),
#  ('medi', 29),
#  ('proc', 29),
#  ('kyph', 27),
#  ('ong</w>', 27),
#  ('tly</w>', 26),
#  ('tern', 26),
#  ('heal', 24),
#  ('on.</w>', 23),
#  ('ling', 23),
#  ('bodi', 22),
#  ('desc', 21),
#  ('sulc', 21),
#  ('or.</w>', 20),
#  ('righ', 19),
#  ('cont', 19),
#  ('stra', 18),
#  ('us.</w>', 18),
#  ('ty.</w>', 18),
#  ('tech', 17),
#  ('sis</w>', 17),
#  ('icd</w>', 17),
#  ('posi', 17),
#  ('obsc', 17),
#  ('ved</w>', 16),
#  ('ular', 15),
#  ('levo', 15),
#  ('form', 15),
#  ('roun', 15),
#  ('segm', 15),
#  ('conv', 14),
#  ('spec', 14),
#  ('fore', 14),
#  ('axil', 14),
#  ('ess</w>', 14),
#  ('cali', 13),
#  ('sion', 12),
#  ('imag', 12),
#  ('shap', 11),
#  ('oid</w>', 11),
#  ('que</w>', 11),
#  ('umer', 11),
#  ('hy.</w>', 10),
#  ('omin', 10),
#  ('in.</w>', 10),
#  ('addi', 10),
#  ('hist', 10),
#  ('ory</w>', 10),
#  ('radi', 10),
#  ('ely</w>', 9),
#  ('hemi', 9),
#  ('obli', 8),
#  ('surg', 8),
#  ('plat', 7),
#  ('curv', 7),
#  ('olog', 7),
#  ('blun', 7),
#  ('ral</w>', 7),
#  ('ulat', 7),
#  ('teri', 6),
#  ('ques', 6),
#  ('exam', 6),
#  ('clin', 6),
#  ('thre', 6),
#  ('tion', 6),
#  ('enti', 6),
#  ('aliz', 6),
#  ('epig', 5),
#  ('ture', 5),
#  ('opla', 5),
#  ('marg', 5),
#  ('lect', 5),
#  ('ic.</w>', 4),
#  ('devi', 4),
#  ('edic', 4),
#  ('anch', 4),
#  ('ater', 4),
#  ('dist', 4),
#  ('prim', 4),
#  ('ophy', 3),
#  ('bron', 3),
#  ('acem', 3),
#  ('trac', 3),
#  ('arti', 2),
#  ('ly.</w>', 2),
#  ('calc', 2),
#  ('sthe', 2),
#  ('ardi', 2),
#  ('ribu', 1),
#  ('reas', 1),
#  ('impl', 1),
#  ('visu', 1),
#  ('thic', 1),
#  ('ard</w>', 1),
#  ('arth', 1),
#  ('metr', 1),
#  ('is</w>', 4059),
#  ('al</w>', 3049),
#  ('or</w>', 2907),
#  ('siz', 1748),
#  ('s.</w>', 1621),
#  ('in</w>', 1330),
#  ('pul', 1087),
#  ('e.</w>', 1060),
#  ('es</w>', 1010),
#  ('ed</w>', 905),
#  ('te</w>', 833),
#  ('th</w>', 784),
#  ('air', 759),
#  ('um</w>', 564),
#  ('mil', 557),
#  ('a.</w>', 485),
#  ('t.</w>', 424),
#  ('app', 385),
#  ('per', 328),
#  ('as</w>', 296),
#  ('lob', 286),
#  ('not', 281),
#  ('mid', 251),
#  ('en</w>', 237),
#  ('on</w>', 231),
#  ('ly</w>', 208),
#  ('se</w>', 194),
#  ('pri', 191),
#  ('ros', 182),
#  ('y.</w>', 161),
#  ('tip', 146),
#  ('le</w>', 145),
#  ('an</w>', 142),
#  ('at</w>', 141),
#  ('asi', 137),
#  ('ing', 134),
#  ('are', 133),
#  ('ft</w>', 130),
#  ('ic</w>', 129),
#  ('aor', 124),
#  ('mas', 123),
#  ('ron', 100),
#  ('sub', 99),
#  ('ve</w>', 96),
#  ('ici', 92),
#  ('bas', 89),
#  ('sho', 84),
#  ('ter', 83),
#  ('wel', 83),
#  ('ele', 81),
#  ('pat', 78),
#  ('est', 72),
#  ('flu', 68),
#  ('ar</w>', 66),
#  ('ent', 65),
#  ('er</w>', 65),
#  ('dy</w>', 62),
#  ('par', 61),
#  ('ver', 58),
#  ('con', 57),
#  ('ath', 56),
#  ('stu', 56),
#  ('nod', 54),
#  ('us</w>', 52),
#  ('rib', 52),
#  ('mul', 51),
#  ('ty</w>', 50),
#  ('ati', 49),
#  ('st</w>', 46),
#  ('ue</w>', 45),
#  ('vic', 44),
#  ('lum', 43),
#  ('cer', 42),
#  ('inc', 41),
#  ('aer', 41),
#  ('two', 40),
#  ('gre', 38),
#  ('tub', 36),
#  ('ect', 33),
#  ('ss</w>', 31),
#  ('ant', 31),
#  ('ast', 30),
#  ('pro', 28),
#  ('low', 28),
#  ('mea', 28),
#  ('rot', 26),
#  ('id</w>', 25),
#  ('cor', 25),
#  ('cav', 24),
#  ('zon', 24),
#  ('oun', 23),
#  ('gh</w>', 21),
#  ('tic', 21),
#  ('sur', 21),
#  ('lat', 21),
#  ('inf', 19),
#  ('ten', 19),
#  ('min', 19),
#  ('ke</w>', 18),
#  ('hil', 18),
#  ('col', 18),
#  ('non', 17),
#  ('rec', 17),
#  ('bul', 17),
#  ('der', 16),
#  ('inj', 15),
#  ('ven', 15),
#  ('pos', 15),
#  ('ge</w>', 15),
#  ('cla', 15),
#  ('ssu', 14),
#  ('ura', 14),
#  ('eni', 14),
#  ('mon', 14),
#  ('val', 14),
#  ('tra', 14),
#  ('mor', 14),
#  ('all', 14),
#  ('ref', 13),
#  ('lec', 13),
#  ('our', 12),
#  ('com', 12),
#  ('end', 12),
#  ('fem', 12),
#  ('vol', 12),
#  ('lar', 12),
#  ('ane', 12),
#  ('sid', 12),
#  ('pel', 12),
#  ('nec', 12),
#  ('lin', 11),
#  ('sen', 11),
#  ('loc', 11),
#  ('m.</w>', 11),
#  ('enc', 11),
#  ('fac', 11),
#  ('sup', 11),
#  ('ext', 11),
#  ('exp', 11),
#  ('str', 11),
#  ('rom', 11),
#  ('por', 10),
#  ('d.</w>', 10),
#  ('int', 10),
#  ('luc', 10),
#  ('ost', 9),
#  ('gra', 9),
#  ('tor', 9),
#  ('red', 9),
#  ('ear', 9),
#  ('ple', 8),
#  ('ful', 8),
#  ('wor', 8),
#  ('ain', 8),
#  ('rem', 8),
#  ('one', 8),
#  ('bro', 8),
#  ('sac', 8),
#  ('asc', 8),
#  ('fil', 8),
#  ('eli', 7),
#  ('ori', 7),
#  ('bac', 7),
#  ('sti', 7),
#  ('ail', 7),
#  ('cop', 6),
#  ('acc', 6),
#  ('asp', 6),
#  ('ac</w>', 6),
#  ('rup', 5),
#  ('de</w>', 5),
#  ('met', 5),
#  ('sto', 5),
#  ('foc', 5),
#  ('hem', 5),
#  ('ili', 5),
#  ('anc', 4),
#  ('cir', 4),
#  ('fol', 4),
#  ('inu', 4),
#  ('den', 4),
#  ('ran', 4),
#  ('ann', 4),
#  ('ess', 4),
#  ('car', 4),
#  ('lim', 4),
#  ('eph', 3),
#  ('tim', 3),
#  ('sli', 3),
#  ('spl', 3),
#  ('pre', 3),
#  ('dis', 3),
#  ('oli', 3),
#  ('yst', 3),
#  ('bil', 3),
#  ('wid', 3),
#  ('ts</w>', 3),
#  ('ure', 3),
#  ('rac', 3),
#  ('res', 2),
#  ('ang', 2),
#  ('unc', 2),
#  ('aph', 2),
#  ('eri', 2),
#  ('iti', 2),
#  ('exc', 2),
#  ('org', 2),
#  ('osi', 1),
#  ('epi', 1),
#  ('tro', 1),
#  ('emp', 1),
#  ('orm', 1),
#  ('gen', 1),
#  ('reg', 1),
#  ('cur', 1),
#  ('mar', 1),
#  ('cal', 1),
#  ('dom', 1),
#  ('foo', 1),
#  ('nar', 1),
#  ('e</w>', 7017),
#  ('no', 4223),
#  ('s</w>', 4090),
#  ('ar', 3979),
#  ('wi', 2367),
#  ('.</w>', 1912),
#  ('a</w>', 1018),
#  ('y</w>', 906),
#  ('t</w>', 786),
#  ('on', 535),
#  ('d</w>', 524),
#  ('se', 425),
#  ('o</w>', 420),
#  ('re', 391),
#  ('ch', 343),
#  ('up', 322),
#  ('at', 316),
#  ('si', 250),
#  ('vi', 230),
#  ('st', 217),
#  ('bo', 203),
#  ('m</w>', 190),
#  ('al', 185),
#  ('th', 173),
#  ('sm', 161),
#  ('ic', 158),
#  ('w</w>', 154),
#  ('ne', 146),
#  ('er', 145),
#  ('ap', 142),
#  ('ro', 124),
#  ('ag', 120),
#  ('le', 113),
#  ('sc', 110),
#  ('h</w>', 109),
#  ('in', 106),
#  ('wh', 105),
#  ('ve', 102),
#  ('ba', 98),
#  ('ol', 96),
#  ('bi', 95),
#  ('lo', 93),
#  ('om', 87),
#  ('be', 80),
#  ('sk', 79),
#  ('l</w>', 75),
#  ('ou', 72),
#  ('di', 69),
#  ('op', 69),
#  ('es', 67),
#  ('en', 66),
#  ('yp', 66),
#  ('an', 65),
#  ('ni', 64),
#  ('un', 62),
#  ('ul', 60),
#  ('ob', 60),
#  ('ra', 58),
#  ('de', 58),
#  ('ac', 57),
#  ('ak', 57),
#  ('su', 55),
#  ('hi', 53),
#  ('um', 51),
#  ('fi', 50),
#  ('ti', 50),
#  ('ab', 49),
#  ('it', 47),
#  ('ur', 41),
#  ('sh', 37),
#  ('im', 36),
#  ('co', 35),
#  ('la', 35),
#  ('as', 35),
#  ('ad', 34),
#  ('ex', 33),
#  ('or', 33),
#  ('ed', 32),
#  ('po', 31),
#  ('ev', 29),
#  ('c</w>', 29),
#  ('il', 28),
#  ('jo', 25),
#  ('ow', 24),
#  ('me', 23),
#  ('oc', 23),
#  ('1</w>', 20),
#  ('2</w>', 18),
#  ('am', 18),
#  ('5</w>', 17),
#  ('ep', 17),
#  ('fe', 17),
#  ('if', 17),
#  ('ew', 16),
#  ('he', 16),
#  ('br', 16),
#  ('el', 15),
#  ('em', 15),
#  ('9</w>', 15),
#  ('li', 15),
#  ('sp', 15),
#  ('gn', 14),
#  ('x</w>', 14),
#  ('te', 14),
#  ('8</w>', 14),
#  ('t1', 14),
#  ('ec', 14),
#  ('0</w>', 13),
#  ('6</w>', 13),
#  ('cu', 12),
#  ('id', 12),
#  ('qu', 11),
#  ('g</w>', 11),
#  ('k</w>', 11),
#  ('av', 10),
#  ('7</w>', 10),
#  ('tu', 10),
#  ('tw', 9),
#  ('mo', 9),
#  ('go', 8),
#  ('4</w>', 8),
#  ('i</w>', 8),
#  ('3</w>', 8),
#  ('ph', 7),
#  ('tr', 7),
#  ('ff', 7),
#  ('pl', 7),
#  ('od', 6),
#  ('ir', 5),
#  ('ri', 5),
#  ('tm', 4),
#  ('sy', 4),
#  ('lu', 3),
#  ('ax', 2),
#  ('et', 2),
#  ('og', 2),
#  ('uc', 2),
#  ('ym', 1),
#  ('is', 1),
#  ('gh', 1),
#  ('os', 1),
#  ('hy', 1),
#  ('pi', 1),
#  ('fo', 1),
#  ('</w>', 7448),
#  ('f', 3013),
#  ('o', 2508),
#  ('b', 967),
#  ('a', 572),
#  ('t', 472),
#  ('g', 408),
#  ('s', 351),
#  ('d', 342),
#  ('h', 258),
#  ('m', 196),
#  ('c', 189),
#  ('v', 179),
#  ('p', 164),
#  ('w', 140),
#  ('u', 113),
#  ('i', 110),
#  ('e', 106),
#  ('n', 83),
#  ('l', 79),
#  ('y', 44),
#  ('1', 42),
#  ('k', 40),
#  ('r', 29),
#  ('j', 25),
#  ('2', 18),
#  ('3', 17),
#  ('6', 14),
#  ('7', 12),
#  ('z', 12),
#  ('5', 12),
#  ('9', 11),
#  ('x', 11),
#  ('4', 9),
#  ('8', 9),
#  ('.', 7),
#  ('0', 5)]

# %%
# %%time
# Tokenise some of the sentences from training data
test_findings_list = test.FINDINGS.values.tolist()
for sentence in test_findings_list[:2]:
    print("Original Sentence= \n")
    print(print(sentence))
    tokenized_sent = []
    for word in sentence.strip().split():
        word = word+'</w>'
        for w in tokenized_postprocessing(word):
            tokenized_sent.append(w)
    print("Tokens=\n")
    print(tokenized_sent, "\n")
# Out:
# Original Sentence=
#
# normal heart size. mild unfolding and atherosclerotic calcification of the aorta. no focal air space consolidation. no pneumothorax or pleural effusion. visualized bony structures are unremarkable in appearance.
# None
# Tokens=
#
# ['norm', 'al</w>', 'heart</w>', 'siz', 'e.</w>', 'mil', 'd</w>', 'unfol', 'ding</w>', 'and</w>', 'atheroscler', 'otic</w>', 'calcific', 'ation</w>', 'o', 'f', '</w>', 'the</w>', 'aort', 'a.</w>', 'no', '</w>', 'focal</w>', 'air</w>', 'space</w>', 'consolid', 'ation.</w>', 'no', '</w>', 'pneumothorax</w>', 'or</w>', 'pleural</w>', 'effu', 'sion.</w>', 'visualiz', 'ed</w>', 'b', 'on', 'y</w>', 'structure', 's</w>', 'ar', 'e</w>', 'unremark', 'able</w>', 'in</w>', 'appearanc', 'e.</w>']
#
# Original Sentence=
#
# heart size normal. lungs are clear. are normal. no pneumonia effusions edema pneumothorax adenopathy nodules or masses.
# None
# Tokens=
#
# ['heart</w>', 'siz', 'e</w>', 'norm', 'al.</w>', 'lung', 's</w>', 'ar', 'e</w>', 'clear', '.</w>', 'ar', 'e</w>', 'norm', 'al.</w>', 'no', '</w>', 'pneumoni', 'a</w>', 'effusion', 's</w>', 'edem', 'a</w>', 'pneumothorax</w>', 'adenop', 'ath', 'y</w>', 'nodul', 'es</w>', 'or</w>', 'mas', 'ses.</w>']
#
# CPU times: user 435 µs, sys: 133 µs, total: 568 µs
# Wall time: 482 µs
